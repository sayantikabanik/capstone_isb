# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Anindita\\Documents\\ISB\\Capstone Project\\Projects\\Capstone Peak Health\\Code\\Text Summarization'

# %% [markdown]
# ### 1. NLTK
#
# - Step 1. Read from source — Read the unabridged content from the source, a file in the case of this exercise.
#
# - Step 2. Perform formatting and cleanup — Format and clean up our format so that it is free of extra white space or other issues.
#
# - Step 3. Tokenize input — Take the input and break it up into its individual words.
#
# - Step 4. Scoring — Score (count) the frequency of each word in the input and score sentences based on word score.
#
# - Step 5. Selection — Choose the top N sentences based on their score.

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from string import punctuation
from nltk.probability import FreqDist
from heapq import nlargest
from collections import defaultdict

# %%
def read_file(path):
    try:
        with open(path, 'r') as file:
            return file.read()
    except IOError as e:
        print("Fatal Error: File ({}) could not be located or is not readable.".format(path))

# %%
def sanitize_input(data):
    replace = {
        ord('\f') : ' ',
        ord('\t') : ' ',
        ord('\n') : ' ',
        ord('\r') : None
    }
    return data.translate(replace)

# %%
def tokenize_content(content):
    stop_words = set(stopwords.words('english') + list(punctuation))
    words = word_tokenize(content.lower())
    
    return [
        sent_tokenize(content),
        [word for word in words if word not in stop_words]    
    ]

# %%
def score_tokens(filtered_words, sentence_tokens):
    word_freq = FreqDist(filtered_words)
    ranking = defaultdict(int)
    for i, sentence in enumerate(sentence_tokens):
        for word in word_tokenize(sentence.lower()):
            if word in word_freq:
                ranking[i] += word_freq[word]
    return ranking

# %%
def summarize(ranks, sentences, length):
    if int(length) > len(sentences): 
        print("Error, more sentences requested than available. Use --l (--length) flag to adjust.")
        exit()
    indexes = nlargest(length, ranks, key=ranks.get)
    final_sentences = [sentences[j] for j in sorted(indexes)]
    return ' '.join(final_sentences)

# %%
content = read_file("testtext.txt")
content = sanitize_input(content)
#print(content,"\n")
sentence_tokens, word_tokens = tokenize_content(content)  
#print(sentence_tokens,"\n")
#print(word_tokens,"\n")
    
sentence_ranks = score_tokens(word_tokens, sentence_tokens)
#print(sentence_ranks,"\n")

print(summarize(sentence_ranks, sentence_tokens, 1))
# Out:
# Not much growth in terms of skills you will be idle in most situations client is god for higher management Good company to start with but no great benefits are there if you are still in your 30s and are in need of a good package Company culture and word life balance is good but the compensation is not there Other companies do provide night shift allowance and pay on national holidays and festivals or at least provide gift to their employees but HCL do nothing like this just provide a comp off that's it that's something need to be changed You need to provide some strong reson to your employees to be in your company for longer period of time you have a job security here and can enjoy along with work as it has gym and games related options.

# %% [markdown]
# ### 2. Gensim

# %%
from gensim.summarization.summarizer import summarize
from gensim.summarization import keywords
# Out:
# C:\Users\Anindita\anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
print ('Summary:')   
print (summarize(str(content), ratio=0.01))
# Out:
# Summary:
# Job security is there Client or Customer centric company and to make client or customer happy they forgot about the engineer Management always listen what the manager says they have set criteria to judge the ratings of engineer or person who is working there but all are fake who makes satisfy the manager only gets good rating and appraisal Before covid they never allowed to engineers any work from home facility It is a growing organization and has multiple mechanical engineering projects currently.
# I have gone through lot of them most of them are useless.Regarding the hike,there isn't even a hike There are 4 quarterly reviews to capture how good you performed in each quarter but it's just a fake game.Everyone in hcl gets almost same hike(usually 6-15%) I joined around 2019 with a fresher salary of 2.5LPA,Then got deployed to these scrap work .Somehow i got lucky .I influenced one of my customers they gave me some important work.Then i learnt and i left .But people who joined along with me are still there struggling to get exposure to market demanding skills.They are stuck and they are not getting any offers in thier hand.I left the organisation with a ctc of 2.6 LPA ie i got a hike of 10k for two years.my request to you is please investigate well and join Hcl Job security is ok here, would suggest to join HCL after 45 or 50 age, as there is no career growth prospects here in HCL.
# Not much growth in terms of skills you will be idle in most situations client is god for higher management Good company to start with but no great benefits are there if you are still in your 30s and are in need of a good package Company culture and word life balance is good but the compensation is not there Other companies do provide night shift allowance and pay on national holidays and festivals or at least provide gift to their employees but HCL do nothing like this just provide a comp off that's it that's something need to be changed You need to provide some strong reson to your employees to be in your company for longer period of time you have a job security here and can enjoy along with work as it has gym and games related options.

# %% [markdown]
# ### 3. Lex Rank

# %%
# !pip install lexrank

# !pip install sumy
# Out:
# Requirement already satisfied: lexrank in c:\users\anindita\anaconda3\lib\site-packages (0.1.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\anindita\anaconda3\lib\site-packages (from lexrank) (1.22.3)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\anindita\anaconda3\lib\site-packages (from lexrank) (0.17.3)
# Requirement already satisfied: urlextract>=0.7 in c:\users\anindita\anaconda3\lib\site-packages (from lexrank) (1.6.0)
# Requirement already satisfied: regex>=2017.11.9 in c:\users\anindita\anaconda3\lib\site-packages (from lexrank) (2021.4.4)
# Requirement already satisfied: path.py>=10.5 in c:\users\anindita\anaconda3\lib\site-packages (from lexrank) (12.5.0)
# Requirement already satisfied: scipy>=0.19.0 in c:\users\anindita\anaconda3\lib\site-packages (from lexrank) (1.8.1)
# Requirement already satisfied: path in c:\users\anindita\anaconda3\lib\site-packages (from path.py>=10.5->lexrank) (15.1.2)
# Requirement already satisfied: platformdirs in c:\users\anindita\anaconda3\lib\site-packages (from urlextract>=0.7->lexrank) (2.5.2)
# Requirement already satisfied: idna in c:\users\anindita\anaconda3\lib\site-packages (from urlextract>=0.7->lexrank) (2.10)
# Requirement already satisfied: uritools in c:\users\anindita\anaconda3\lib\site-packages (from urlextract>=0.7->lexrank) (4.0.0)
# Requirement already satisfied: filelock in c:\users\anindita\anaconda3\lib\site-packages (from urlextract>=0.7->lexrank) (3.0.12)
# Requirement already satisfied: sumy in c:\users\anindita\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: breadability>=0.1.20 in c:\users\anindita\anaconda3\lib\site-packages (from sumy) (0.1.20)
# Requirement already satisfied: nltk>=3.0.2 in c:\users\anindita\anaconda3\lib\site-packages (from sumy) (3.6.1)
# Requirement already satisfied: pycountry>=18.2.23 in c:\users\anindita\anaconda3\lib\site-packages (from sumy) (22.3.5)
# Requirement already satisfied: docopt<0.7,>=0.6.1 in c:\users\anindita\anaconda3\lib\site-packages (from sumy) (0.6.2)
# Requirement already satisfied: requests>=2.7.0 in c:\users\anindita\anaconda3\lib\site-packages (from sumy) (2.25.1)
# Requirement already satisfied: lxml>=2.0 in c:\users\anindita\anaconda3\lib\site-packages (from breadability>=0.1.20->sumy) (4.6.3)
# Requirement already satisfied: chardet in c:\users\anindita\anaconda3\lib\site-packages (from breadability>=0.1.20->sumy) (4.0.0)
# Requirement already satisfied: joblib in c:\users\anindita\anaconda3\lib\site-packages (from nltk>=3.0.2->sumy) (1.0.1)
# Requirement already satisfied: click in c:\users\anindita\anaconda3\lib\site-packages (from nltk>=3.0.2->sumy) (7.1.2)
# Requirement already satisfied: tqdm in c:\users\anindita\anaconda3\lib\site-packages (from nltk>=3.0.2->sumy) (4.64.0)
# Requirement already satisfied: regex in c:\users\anindita\anaconda3\lib\site-packages (from nltk>=3.0.2->sumy) (2021.4.4)
# Requirement already satisfied: setuptools in c:\users\anindita\anaconda3\lib\site-packages (from pycountry>=18.2.23->sumy) (52.0.0.post20210125)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\anindita\anaconda3\lib\site-packages (from requests>=2.7.0->sumy) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\anindita\anaconda3\lib\site-packages (from requests>=2.7.0->sumy) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anindita\anaconda3\lib\site-packages (from requests>=2.7.0->sumy) (2022.5.18.1)
# Requirement already satisfied: colorama in c:\users\anindita\anaconda3\lib\site-packages (from tqdm->nltk>=3.0.2->sumy) (0.4.4)

# %%
from lexrank import LexRank
from lexrank.mappings.stopwords import STOPWORDS
from path import Path

from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lex_rank import LexRankSummarizer

# %%
parser=PlaintextParser.from_file("testtext.txt",Tokenizer("english"))
# Using LexRank
summarizer = LexRankSummarizer()
#Summarize the document with 4 sentences
summary = summarizer(parser.document,1)
for sentence in summary:
    print(sentence)
# Out:
# Not much growth in terms of skills you will be idle in most situations client is god for higher management Good company to start with but no great benefits are there if you are still in your 30s and are in need of a good package Company culture and word life balance is good but the compensation is not there Other companies do provide night shift allowance and pay on national holidays and festivals or at least provide gift to their employees but HCL do nothing like this just provide a comp off that's it that's something need to be changed You need to provide some strong reson to your employees to be in your company for longer period of time you have a job security here and can enjoy along with work as it has gym and games related options.

# %%
from sumy.summarizers.lsa import LsaSummarizer
from sumy.nlp.stemmers import Stemmer
from sumy.utils import get_stop_words
 
from sumy.summarizers.luhn import LuhnSummarizer
from sumy.summarizers.edmundson import EdmundsonSummarizer
from sumy.summarizers.kl import KLSummarizer
from sumy.summarizers.text_rank import TextRankSummarizer
from sumy.summarizers.reduction import ReductionSummarizer

# %%
LANGUAGE = "english"
SENTENCES_COUNT = 2

if __name__ == "__main__":
    parser = PlaintextParser.from_file("testtext.txt", Tokenizer(LANGUAGE))

 
    print ("\033[1m LsaSummarizer \033[0m")
    summarizer = LsaSummarizer(Stemmer(LANGUAGE))#Latent Semantic Analysis
    summarizer.stop_words = get_stop_words(LANGUAGE)
    for sentence in summarizer(parser.document, SENTENCES_COUNT):
        print(sentence)
         
    print ("\033[1m LuhnSummarizer \033[0m")     
    summarizer = LuhnSummarizer(Stemmer(LANGUAGE)) #Word freq method
    summarizer.stop_words = ("I", "am", "the", "you", "are", "me", "is", "than", "that", "this",)
    for sentence in summarizer(parser.document, SENTENCES_COUNT):
        print(sentence)
         
    print ("\033[1m EdmundsonSummarizer \033[0m")     
    summarizer = EdmundsonSummarizer() #cue phrase method
    words = ("deep", "learning", "neural" )
    summarizer.bonus_words = words
    words = ("another", "and", "some", "next",)
    summarizer.stigma_words = words
    words = ("another", "and", "some", "next",)
    summarizer.null_words = words
    for sentence in summarizer(parser.document, SENTENCES_COUNT):
        print(sentence)   
        
    print("\033[1m KL Summarizer \033[0m")
    summarizer = KLSummarizer()
    for sentence in summarizer(parser.document, SENTENCES_COUNT):
        print(sentence)
        
    print("\033[1m TextRank Summarizer \033[0m")
    summarizer = TextRankSummarizer()
    for sentence in summarizer(parser.document, SENTENCES_COUNT):
        print(sentence)
        
    print("\033[1m Reduction Summarizer \033[0m")
    summarizer = ReductionSummarizer()
    for sentence in summarizer(parser.document, SENTENCES_COUNT):
        print(sentence)
# Out:
#  LsaSummarizer
# There was a notification of walkin interview on naukri.com , the company clearly mentioned , to show the notification to the ground floor security , other wise they'll not let you enter , I reached the company on time , the security guard asked me about the mail , I showed him the notification , but he refused to let me enter , I also told him that this is what companies permission is but still he refused , I showed him the date and venue in the notification but he did not bulge , on contrary he's behaviour was very rude, and seems to be throwing his weight around , when I asked him again he started raising his voice , shouting and misbehaving , I went to the watchmans manager who was seeing all this from distance , and he asked me to leave , I again politely explained him every thing , but he just showed me the gate , I had placed a leave for this interview , and came all the way from L B nagar , quite far away from hitec city, and this is what you get , and it's not just hcl , it happens in most of the multinationals , watchmans and security guards play important part in recruitment drive , as it's they who decide who should enter , who should not , and coming to hcl , if you don't want candidates to enter the building , please keep an HR in the security guard room itself , it might be helpful for both of us , the first 6 months were terrible, there may be in place pieces of training and other things but those who have gone through some technical concepts, you have already done that.
# Pros: Job security Open for learning Work life balance Free cabs Cons: No/micro annual hikes Micro management Office politics While leaving d company you have to pay hefty sum of amounts All trainings comes with a bond or agreements.
#  LuhnSummarizer
# You wil get career growth if you joined in internal projects.If it is a service-based project (external project from other vendors ) my request is please don't join.Because you will end being nothing.Most of the product developement companies give the documentation andless important works to these kind of service companies.If you joined here you will get deployed these mokka(scrap) works.These companies uses their own tools for product development and you will be forced to work on these tools .In effect after two or three years you will use only those tools and your skills won't get updated as per the market level.When you come out of the organisation your market value will be nothing.If you ask for different role what they does is they will deploy in some other project where you will have to use some other mokka tools.Yes there are exceptions but it depends on your luck.99% of the people who joined in external project suffers.Client will treat you like a begger .They toss away all the scrap works to you and they will do the intresting work.
# Not much growth in terms of skills you will be idle in most situations client is god for higher management Good company to start with but no great benefits are there if you are still in your 30s and are in need of a good package Company culture and word life balance is good but the compensation is not there Other companies do provide night shift allowance and pay on national holidays and festivals or at least provide gift to their employees but HCL do nothing like this just provide a comp off that's it that's something need to be changed You need to provide some strong reson to your employees to be in your company for longer period of time you have a job security here and can enjoy along with work as it has gym and games related options.
#  EdmundsonSummarizer
# Yes they offers a very good learning platform like isuccess learning but those courses are worst.
# Enough learning opportunities inside 4.
#  KL Summarizer
# company policies are good , appraisals are fair and they give good salary hike and bonus every year Management is good work life balance is good.
# Job security is there in hcl and they have lot of projects.
#  TextRank Summarizer
# You wil get career growth if you joined in internal projects.If it is a service-based project (external project from other vendors ) my request is please don't join.Because you will end being nothing.Most of the product developement companies give the documentation andless important works to these kind of service companies.If you joined here you will get deployed these mokka(scrap) works.These companies uses their own tools for product development and you will be forced to work on these tools .In effect after two or three years you will use only those tools and your skills won't get updated as per the market level.When you come out of the organisation your market value will be nothing.If you ask for different role what they does is they will deploy in some other project where you will have to use some other mokka tools.Yes there are exceptions but it depends on your luck.99% of the people who joined in external project suffers.Client will treat you like a begger .They toss away all the scrap works to you and they will do the intresting work.
# There was a notification of walkin interview on naukri.com , the company clearly mentioned , to show the notification to the ground floor security , other wise they'll not let you enter , I reached the company on time , the security guard asked me about the mail , I showed him the notification , but he refused to let me enter , I also told him that this is what companies permission is but still he refused , I showed him the date and venue in the notification but he did not bulge , on contrary he's behaviour was very rude, and seems to be throwing his weight around , when I asked him again he started raising his voice , shouting and misbehaving , I went to the watchmans manager who was seeing all this from distance , and he asked me to leave , I again politely explained him every thing , but he just showed me the gate , I had placed a leave for this interview , and came all the way from L B nagar , quite far away from hitec city, and this is what you get , and it's not just hcl , it happens in most of the multinationals , watchmans and security guards play important part in recruitment drive , as it's they who decide who should enter , who should not , and coming to hcl , if you don't want candidates to enter the building , please keep an HR in the security guard room itself , it might be helpful for both of us , the first 6 months were terrible, there may be in place pieces of training and other things but those who have gone through some technical concepts, you have already done that.
#  Reduction Summarizer
# You wil get career growth if you joined in internal projects.If it is a service-based project (external project from other vendors ) my request is please don't join.Because you will end being nothing.Most of the product developement companies give the documentation andless important works to these kind of service companies.If you joined here you will get deployed these mokka(scrap) works.These companies uses their own tools for product development and you will be forced to work on these tools .In effect after two or three years you will use only those tools and your skills won't get updated as per the market level.When you come out of the organisation your market value will be nothing.If you ask for different role what they does is they will deploy in some other project where you will have to use some other mokka tools.Yes there are exceptions but it depends on your luck.99% of the people who joined in external project suffers.Client will treat you like a begger .They toss away all the scrap works to you and they will do the intresting work.
# There was a notification of walkin interview on naukri.com , the company clearly mentioned , to show the notification to the ground floor security , other wise they'll not let you enter , I reached the company on time , the security guard asked me about the mail , I showed him the notification , but he refused to let me enter , I also told him that this is what companies permission is but still he refused , I showed him the date and venue in the notification but he did not bulge , on contrary he's behaviour was very rude, and seems to be throwing his weight around , when I asked him again he started raising his voice , shouting and misbehaving , I went to the watchmans manager who was seeing all this from distance , and he asked me to leave , I again politely explained him every thing , but he just showed me the gate , I had placed a leave for this interview , and came all the way from L B nagar , quite far away from hitec city, and this is what you get , and it's not just hcl , it happens in most of the multinationals , watchmans and security guards play important part in recruitment drive , as it's they who decide who should enter , who should not , and coming to hcl , if you don't want candidates to enter the building , please keep an HR in the security guard room itself , it might be helpful for both of us , the first 6 months were terrible, there may be in place pieces of training and other things but those who have gone through some technical concepts, you have already done that.

# %% [markdown]
# ### TL-DR

# %%
import nltk
import string
from heapq import nlargest

# %%
# If the length of the text is greater than 20, take a 10th of the sentences
if content.count(". ") > 500:
    length = int(round(content.count(". ")/10, 0))
# Otherwise return five sentences
else:
    length = 1

# %%
# Remove punctuation
nopunc = [char for char in content if char not in string.punctuation]
nopunc = ''.join(nopunc)
# Remove stopwords
processed_text =[word for word in nopunc.split() if word.lower() not in nltk.corpus.stopwords.words('english')]

# %%
# Create a dictionary to store word frequency
word_freq = {}
# Enter each word and its number of occurrences
for word in processed_text:
    if word not in word_freq:
        word_freq[word] = 1
    else:
        word_freq[word] = word_freq[word] + 1

# %%
# Divide all frequencies by max frequency to give store of (0, 1]
max_freq = max(word_freq.values())
for word in word_freq.keys():
    word_freq[word] = (word_freq[word]/max_freq)

# %%
# Create a list of the sentences in the text
sent_list = nltk.sent_tokenize(content)
# Create an empty dictionary to store sentence scores
sent_score = {}
for sent in sent_list:
    for word in nltk.word_tokenize(sent.lower()):
        if word in word_freq.keys():
            if sent not in sent_score.keys():
                sent_score[sent] = word_freq[word]
            else:
                sent_score[sent] = sent_score[sent] + word_freq[word]

# %%
summary_sents = nlargest(length, sent_score, key = sent_score.get)
summary = ' '.join(summary_sents)
print(summary)
# Out:
# Not much growth in terms of skills you will be idle in most situations client is god for higher management Good company to start with but no great benefits are there if you are still in your 30s and are in need of a good package Company culture and word life balance is good but the compensation is not there Other companies do provide night shift allowance and pay on national holidays and festivals or at least provide gift to their employees but HCL do nothing like this just provide a comp off that's it that's something need to be changed You need to provide some strong reson to your employees to be in your company for longer period of time you have a job security here and can enjoy along with work as it has gym and games related options.

# %% [markdown]
# ### PyTextRank

# %%
# !pip install pytextrank
# !python -m spacy download en_core_web_sm
# Out:
# Collecting pytextrank
#   Using cached pytextrank-3.2.3-py3-none-any.whl (30 kB)
# Requirement already satisfied: pygments>=2.7.4 in c:\users\anindita\anaconda3\lib\site-packages (from pytextrank) (2.8.1)
# Collecting graphviz>=0.13
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
# Requirement already satisfied: networkx[default]>=2.6 in c:\users\anindita\anaconda3\lib\site-packages (from pytextrank) (2.7)
# Requirement already satisfied: spacy>=3.0 in c:\users\anindita\anaconda3\lib\site-packages (from pytextrank) (3.2.4)
# Requirement already satisfied: scipy>=1.7 in c:\users\anindita\anaconda3\lib\site-packages (from pytextrank) (1.8.1)
# Collecting icecream>=2.1
#   Downloading icecream-2.1.3-py2.py3-none-any.whl (8.4 kB)
# Collecting asttokens>=2.0.1
#   Using cached asttokens-2.0.5-py2.py3-none-any.whl (20 kB)
# Collecting executing>=0.3.1
#   Downloading executing-0.9.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: colorama>=0.3.9 in c:\users\anindita\anaconda3\lib\site-packages (from icecream>=2.1->pytextrank) (0.4.4)
# Requirement already satisfied: six in c:\users\anindita\anaconda3\lib\site-packages (from asttokens>=2.0.1->icecream>=2.1->pytextrank) (1.15.0)
# Requirement already satisfied: pandas>=1.3 in c:\users\anindita\anaconda3\lib\site-packages (from networkx[default]>=2.6->pytextrank) (1.4.3)
# Requirement already satisfied: numpy>=1.19 in c:\users\anindita\anaconda3\lib\site-packages (from networkx[default]>=2.6->pytextrank) (1.22.3)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\anindita\appdata\roaming\python\python38\site-packages (from networkx[default]>=2.6->pytextrank) (3.5.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\anindita\anaconda3\lib\site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (2.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\anindita\anaconda3\lib\site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (20.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\anindita\anaconda3\lib\site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anindita\anaconda3\lib\site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\anindita\anaconda3\lib\site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (8.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\anindita\anaconda3\lib\site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anindita\anaconda3\lib\site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (4.34.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anindita\anaconda3\lib\site-packages (from pandas>=1.3->networkx[default]>=2.6->pytextrank) (2021.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\anindita\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (0.4.1)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\anindita\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (0.6.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\anindita\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (1.0.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\anindita\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (1.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\anindita\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (3.0.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\users\anindita\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (8.0.15)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\anindita\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (4.64.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\anindita\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (2.0.7)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\anindita\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (0.7.7)
# Requirement already satisfied: setuptools in c:\users\anindita\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (52.0.0.post20210125)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\anindita\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (2.25.1)
# Requirement already satisfied: jinja2 in c:\users\anindita\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (2.11.3)
# Requirement already satisfied: click<8.1.0 in c:\users\anindita\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (7.1.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\anindita\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (3.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\anindita\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (2.4.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\anindita\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (0.9.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\anindita\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (3.0.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\anindita\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (1.8.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\anindita\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (2.0.6)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\anindita\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy>=3.0->pytextrank) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\anindita\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy>=3.0->pytextrank) (3.7.4.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\anindita\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\anindita\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anindita\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\anindita\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (2.10)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\anindita\anaconda3\lib\site-packages (from jinja2->spacy>=3.0->pytextrank) (1.1.1)
# Installing collected packages: executing, asttokens, icecream, graphviz, pytextrank
# Successfully installed asttokens-2.0.5 executing-0.9.0 graphviz-0.20.1 icecream-2.1.3 pytextrank-3.2.3
# Collecting en-core-web-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in c:\users\anindita\anaconda3\lib\site-packages (from en-core-web-sm==3.2.0) (3.2.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\anindita\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\anindita\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\anindita\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\anindita\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\anindita\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\anindita\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\anindita\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (20.9)
# Requirement already satisfied: setuptools in c:\users\anindita\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (52.0.0.post20210125)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\anindita\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\anindita\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.25.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\anindita\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\anindita\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.9.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\anindita\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.22.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\anindita\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\users\anindita\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.15)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\anindita\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\anindita\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.7.7)
# Requirement already satisfied: jinja2 in c:\users\anindita\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.11.3)
# Requirement already satisfied: click<8.1.0 in c:\users\anindita\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (7.1.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\anindita\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.64.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\anindita\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\anindita\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\anindita\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\anindita\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.7.4.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\anindita\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anindita\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\anindita\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\anindita\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.26.4)
# Requirement already satisfied: colorama in c:\users\anindita\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\anindita\anaconda3\lib\site-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# 2022-07-26 16:02:19.832810: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-07-26 16:02:19.833027: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
import spacy
import pytextrank

# %%
en_nlp = spacy.load("en_core_web_sm")
en_nlp.add_pipe("textrank")
doc = en_nlp(content)

# %%
for combination in doc._.phrases:
    print(combination.text, combination.rank, combination.count)
# Out:
# Good work 0.091465941190635 1
# Good work environment 0.08851008437063486 5
# good work life balance 0.08724648347656681 1
# good job security 0.0855892799422587 1
# higher management Good company 0.08332342256445688 1
# good salary hike 0.0831587028186492 7
# good banking projects 0.08300550671783283 1
# Good training 0.08028788994474875 1
# good opportunity 0.07983464999239352 2
# good culture 0.07903111656661684 1
# good place 0.07644995334101981 2
# Good learning 0.07544460778957043 1
# good rating 0.07527916090313254 3
# good package 0.07472332866029903 1
# Good learning environment 0.07468425687280983 1
# Good cafeteria 0.07430376605789342 1
# good working culture 0.0740938778844844 1
# good worker 0.07375625636872718 1
# good learner 0.07347023684182166 1
# good rest 0.07335794708793617 1
# Good Experience 0.07293555900745397 1
# avery good organization 0.06956938826420953 1
# Company job security 0.06933894073611542 1
# Overall good experience 0.068504808201687 1
# good increment orelse 0.06829581811564385 1
# Overall good Company 0.06804645169178067 1
# HCL company 0.06752168597909233 1
# project management 0.06730618466618457 1
# Work life balance 0.06698506891394337 5
# work life balance 0.06698506891394337 5
# Work culture 0.06405844134551004 1
# work culture 0.06405844134551004 3
# Work environment 0.06348666258385474 1
# Work pressure 0.06128302249018239 1
# work pressure 0.06128302249018239 1
# work place 0.06084539331530432 1
# Work life balance Free cabs 0.059897661963777445 1
# work 0.059167275730364705 6
# Normal work environment 0.05900994715497885 1
# Job security 0.058548079193775256 13
# job security 0.058548079193775256 6
# Other companies 0.05729667233353453 1
# other company 0.05729667233353453 1
# work load 0.05717233344714237 1
# work tenure 0.05686824431285839 1
# hard work 0.05654814486843247 1
# high job security 0.056103583055714765 1
# Company policies 0.05574601318908218 4
# Company policy 0.05574601318908218 1
# company policies 0.05574601318908218 3
# good, perfect work life balance 0.05534941154720721 1
# project 0.055261994907018636 3
# projects 0.055261994907018636 8
# Service Desk work 0.0550071859548201 1
# multiple projects 0.054820208045057356 1
# awesome job security 0.05461689855950477 1
# andless important works 0.054166251451013156 1
# external project 0.053932455659712844 1
# project lead 0.05376455295971566 1
# many projects 0.05372864658787433 1
# project availability 0.05343388062784618 1
# internal projects 0.053232238304201936 1
# java projects 0.0532248671890348 1
# time salary payment 0.052589663310239385 1
# employee based roles 0.052399041525885676 1
# HCL technologies 0.05227147560095408 1
# multiple banking projects 0.051980083041272204 1
# bank related project 0.0512346017475198 1
# cen percente job security 0.05091208305801381 1
# a good package Company culture 0.05090670516213626 1
# skill based trainings 0.05079767759920514 1
# HCL 0.050743663069459544 43
# service companies 0.05064962130881022 1
# Company 0.05053865842535511 1
# company 0.05053865842535511 4
# HCL Techbee 0.05032642553778328 2
# HCL Technologies 0.05030233164531564 3
# JOIN HCL 0.04970160775952541 1
# Learning opportunities 0.04928819814985258 1
# join HCL 0.049057079712222895 1
# monthly salary 0.049051087364557655 1
# HCL perspective 0.0490005818014295 1
# companies permission 0.04882763883760201 1
# HCL Healthcare 0.04856112819142109 1
# developement companies 0.04855142630684772 1
# multiple mechanical engineering projects 0.04852057687925562 1
# Employee 0.04844846615632164 1
# Employees 0.04844846615632164 1
# employee 0.04844846615632164 3
# employees 0.04844846615632164 8
# employees problems 0.048373506926435744 1
# whole HCL 0.04830345151102247 1
# 2.HCL 0.007068027635456652 2
# Freedom 0.007068027635456652 1
# Learning 0.007068027635456652 1
# People 0.007068027635456652 4
# Trainer 0.007068027635456652 1
# case 0.007068027635456652 1
# juniors 0.007068027635456652 1
# wil 0.007068027635456652 1
# 2 lakhs 0.00700980738170173 2
# no one 0.006931578997120872 2
# every week 0.006917761870186199 1
# a brand 0.006781705856719527 1
# 100 reasons 0.006750187391506544 1
# any reason 0.006750187391506544 1
# the date 0.006670431413857427 1
# no clue 0.006424989296690451 1
# a comp 0.0063771348071187985 1
# a billable resource 0.00631881305408109 1
# a experienced resource 0.00631881305408109 1
# one (contribution 0.0062211693831159195 1
# my Project 0.00621346601620178 1
# two years.my request 0.006182482839974246 1
# the multinationals 0.006040330050651913 1
# any kind 0.005850052894746712 1
# these kind 0.005850052894746712 1
# all codes 0.005794687341198205 1
# all section 0.005753042753315441 1
# the hell 0.005745468529356459 1
# his weight 0.005698597540067296 1
# any f&f 0.005585786725094501 1
# nothing increases 0.005579901901661247 1
# what profile 0.005573714210560753 1
# the building 0.005456923764359901 1
# No transport 0.005447234741516623 1
# chilling.company police 0.005438286121739295 1
# chilling.company polices 0.005438286121739295 1
# your co 0.005431741259970035 1
# no change 0.005410155548969079 1
# a bond 0.005370168980430173 1
# my doubts 0.005336966505127151 1
# your 30s 0.005333278290437989 1
# the globe 0.005332501266732665 1
# 2.6 LPA 0.005319792816277675 1
# my family 0.0053076121528928405 1
# his voice 0.005270196142628192 1
# the gate 0.005247705776018448 1
# these actions 0.005238439263338649 1
# a provision 0.005135237120235387 1
# the mail 0.005134694731635048 1
# Those titles 0.0050673718974425 1
# these titles 0.0050673718974425 1
# even a doctrate 0.0050477146713803454 1
# 9 percent 0.0050260855889876195 2
# 90 percent 0.0050260855889876195 2
# only a week 0.005023570596798716 2
# a slave 0.005021490137593447 1
# 50+ countries 0.005000438930155856 1
# the documentation 0.00494123706451543 1
# the formalities 0.004889000451390541 1
# any RnR 0.004837156038417105 1
# "Architect 0.004832877790075009 1
# these mokka(scrap 0.004757308875153649 1
# a ctc 0.004696336726686204 1
# my RM 0.004467817290075434 1
# the number 0.004405725683518551 1
# some sweets 0.004401131500709591 1
# all the scrap 0.004188986241636447 1
# a begger 0.004098930126492579 1
# the fortune 0.003883085127800133 1
# 2 types 0.003698306126616851 1
# Over 11 B 0.0036358364451053587 1
# no barrier 0.00359939934292366 1
# no transparency 0.00359939934292366 1
# B. Those 0.00326458212637649 2
# 45 or 50 age 0.0030974411335859165 1
# Only my collegues 0.0023706885389592263 1
# # 0.0 1
# 1 0.0 7
# 1/2 0.0 1
# 100 0.0 1
# 11 0.0 1
# 123 0.0 1
# 2 0.0 8
# 2,38,000 0.0 2
# 2.6 0.0 1
# 3 0.0 7
# 4 0.0 9
# 45 0.0 1
# 5 0.0 4
# 50 0.0 1
# 6 0.0 3
# 7 0.0 1
# 8 0.0 1
# Everyone 0.0 1
# First 0.0 1
# I 0.0 52
# It 0.0 4
# Its 0.0 1
# Nothing 0.0 4
# One 0.0 2
# They 0.0 15
# This 0.0 4
# We 0.0 1
# You 0.0 11
# all 0.0 4
# all this 0.0 1
# annually 0.0 1
# anyone 0.0 1
# anything 0.0 5
# both 0.0 1
# everything 0.0 4
# he 0.0 10
# him 0.0 5
# i 0.0 9
# it 0.0 30
# itself 0.0 1
# me 0.0 13
# naukri.com 0.0 1
# not all 0.0 1
# nothing 0.0 5
# one 0.0 6
# something 0.0 3
# that 0.0 11
# them 0.0 5
# ther 0.0 1
# they 0.0 58
# this 0.0 9
# those 0.0 1
# two 0.0 1
# us 0.0 2
# we 0.0 5
# what 0.0 6
# whatever 0.0 1
# which 0.0 12
# who 0.0 19
# whoever 0.0 1
# you 0.0 108
# yours 0.0 1
# yourself 0.0 1
# zero 0.0 1

# %%
en_nlp = spacy.load("en_core_web_sm")
en_nlp.add_pipe("textrank", config={ "stopwords": { "word": ["NOUN"] } })
doc = en_nlp(content)
for phrase in doc._.phrases[:5]:
    print(phrase)
# Out:
# Phrase(text='Good work', chunks=[Good work], count=1, rank=0.09143881676920286)
# Phrase(text='Good work environment', chunks=[Good work environment, Good work environment, Good work environment, Good work environment, Good work environment], count=5, rank=0.0884850950162702)
# Phrase(text='good work life balance', chunks=[good work life balance], count=1, rank=0.08713796492577786)
# Phrase(text='good job security', chunks=[good job security], count=1, rank=0.08555192670598187)
# Phrase(text='higher management Good company', chunks=[higher management Good company], count=1, rank=0.08330559422272783)

# %%
tr = doc._.textrank

# %%
for sent in tr.summary(limit_phrases=10, limit_sentences=2):
    print(sent)
# Out:
# company policies are good , appraisals are fair and they give good salary hike and bonus every year Management is good work life balance is good.
# Good work and environment and culture.temmates are supportive and the management is transparent.tjere is a huge cafeteria and gaming arcade for chilling .

# %% [markdown]
# ### Using SUMMA Package

# %%
# !pip install summa
# Out:
# Requirement already satisfied: summa in c:\users\anindita\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: scipy>=0.19 in c:\users\anindita\anaconda3\lib\site-packages (from summa) (1.8.1)
# Requirement already satisfied: numpy<1.25.0,>=1.17.3 in c:\users\anindita\anaconda3\lib\site-packages (from scipy>=0.19->summa) (1.22.3)

# %%
from summa import summarizer
from summa import keywords

# %%
print(summarizer.summarize(content))
# Out:
# Job security is there Client or Customer centric company and to make client or customer happy they forgot about the engineer Management always listen what the manager says they have set criteria to judge the ratings of engineer or person who is working there but all are fake who makes satisfy the manager only gets good rating and appraisal Before covid they never allowed to engineers any work from home facility It is a growing organization and has multiple mechanical engineering projects currently.
# Hcl is avery good organization,But the middle management is shit.
# You wil get career growth if you joined in internal projects.If it is a service-based project (external project from other vendors ) my request is please don't join.Because you will end being nothing.Most of the product developement companies give the documentation andless important works to these kind of service companies.If you joined here you will get deployed these mokka(scrap) works.These companies uses their own tools for product development and you will be forced to work on these tools .In effect after two or three years you will use only those tools and your skills won't get updated as per the market level.When you come out of the organisation your market value will be nothing.If you ask for different role what they does is they will deploy in some other project where you will have to use some other mokka tools.Yes there are exceptions but it depends on your luck.99% of the people who joined in external project suffers.Client will treat you like a begger .They toss away all the scrap works to you and they will do the intresting work.
# I have gone through lot of them most of them are useless.Regarding the hike,there isn't even a hike There are 4 quarterly reviews to capture how good you performed in each quarter but it's just a fake game.Everyone in hcl gets almost same hike(usually 6-15%) I joined around 2019 with a fresher salary of 2.5LPA,Then got deployed to these scrap work .Somehow i got lucky .I influenced one of my customers they gave me some important work.Then i learnt and i left .But people who joined along with me are still there struggling to get exposure to market demanding skills.They are stuck and they are not getting any offers in thier hand.I left the organisation with a ctc of 2.6 LPA ie i got a hike of 10k for two years.my request to you is please investigate well and join Hcl Job security is ok here, would suggest to join HCL after 45 or 50 age, as there is no career growth prospects here in HCL.
# Manager's allways harassing their people mostly the manager came from Service Desk Management Salary - forget about that you will get hike every year , they do nothing increases, There is called quarterly performance review , they will give allways good rating all quarter but at the end of year like annual review they will mark down your review with out having any reason.
# Nothing There is no such thing that i like the work there because ther are no benefits provided to the employees and it is not employee centric The company has good working culture and also provides job security.
# As per my experience, Job security is there but working environment is worse, you are like a slave.
# Good work environment and culture.
# Company policies are good, appraisals are fair and they give good salary hike and bonus every year.
# job security: sometime luckily u get 1 yr, projects, mostly 3-6 month projects only so ready to attend customer interview often, if ur good in clearing it then fine, after 4 chances they ask u resign.
# Hcl Lucknow only can give you job security, it is not good place for anything else.
# However if you are a experienced resource who believes in a professional work environment, good work life balance, appriciation for your good job.
# I never recommend anyone to join this organization Hey I have a total work experience of almost 4 years where I found HCL is the company where I can spend time for me and with my family without any issue the work life balance is the ultimate thing in any environment where I found its abundant in my project.
# Job security is good.
# Since HCL is top 4 companies in terms of revenue Over 11 B and it's presence in 50+ countries why do they charge 2,38,000 from students stating candidate will be trained on software curriculum (which means Excel,access) works few concepts of programing and DBMS which cost less than 25k but why they charge 2.38L 2.When this program is in Australia they don't charge a single penny during 3 months which is foundation classes (if candidate feel ok of the curriculum then he goes ahead but here in India they ask you to go bank loan giving enough fake promises of not required to pay interest until u get job in HCL) which has raise my doubts on the program Since HCL is Hindustani computer limited company why they looting indian money rather they don't focus the same in Other countries bcz they feel Indians are fools 3.
# Good work environment and culture.
# Company policies are good, appraisals are fair and they give good salary hike and bonus every year.
# Work-Life balance and job security is good.
# So if you are looking for a job with avarage pay out and relaxed work with out any major upskilling, then its a good place for you.
# Company job security is better than other consulting firm such as Tech Mahindra but not as much as TCS, Infosys Company is good, perfect work life balance.
# I work here for salary and if a manager and organisation can cut a employee salary stating their performance both on monthly and annually.
# Job security is good, work culture - no much pressure or tight deadlines.
# Good work and environment and culture.temmates are supportive and the management is transparent.tjere is a huge cafeteria and gaming arcade for chilling .
# company policies are good , appraisals are fair and they give good salary hike and bonus every year Management is good work life balance is good.
# Not much growth in terms of skills you will be idle in most situations client is god for higher management Good company to start with but no great benefits are there if you are still in your 30s and are in need of a good package Company culture and word life balance is good but the compensation is not there Other companies do provide night shift allowance and pay on national holidays and festivals or at least provide gift to their employees but HCL do nothing like this just provide a comp off that's it that's something need to be changed You need to provide some strong reson to your employees to be in your company for longer period of time you have a job security here and can enjoy along with work as it has gym and games related options.
# But annual compensation will be not as per the expectation.Overall it is good with working and learning point of view but stay for long lasting will not keep the salary as expected.
# Job security is not there, worst management,, the HR also not supported for employees they only support for project lead, leads are using company policies in wrong way, I HCL not solve employees problems They only saw lead feedback.
# Only good thing that HCL offers is a job Security Regarding growth and other things it depends on the process to process.
# No other benefits, work culture and management will not help you to grow.
# Good work environment and culture.
# Company policies are good, appraisals are fair and they give good salary hike and bonus on time.
# 2. Managers are mostly good and won't give much pressure to employees 3.
# Gaming arcade for chilling.company police's are good, they give good salary hike and bonus every year.
# Good work environment and culture.teammates are supportive and the management is transparent.
# There is a huge cafeteria and gaming arcade for chilling.company polices are good, appraisals are fair and they give good salary hike and bonus every year One of the best company, I have worked so far.
# 1. Job security is very good with employees having a provision to switch roles on need basis/ as he requires.
# 3. Work life balance is very good with enough flexibility to align your professional and personal life.
# Good work environment and culture.
# Management is good for some teams but not all.
# Job security is very good.
# There was a notification of walkin interview on naukri.com , the company clearly mentioned , to show the notification to the ground floor security , other wise they'll not let you enter , I reached the company on time , the security guard asked me about the mail , I showed him the notification , but he refused to let me enter , I also told him that this is what companies permission is but still he refused , I showed him the date and venue in the notification but he did not bulge , on contrary he's behaviour was very rude, and seems to be throwing his weight around , when I asked him again he started raising his voice , shouting and misbehaving , I went to the watchmans manager who was seeing all this from distance , and he asked me to leave , I again politely explained him every thing , but he just showed me the gate , I had placed a leave for this interview , and came all the way from L B nagar , quite far away from hitec city, and this is what you get , and it's not just hcl , it happens in most of the multinationals , watchmans and security guards play important part in recruitment drive , as it's they who decide who should enter , who should not , and coming to hcl , if you don't want candidates to enter the building , please keep an HR in the security guard room itself , it might be helpful for both of us , the first 6 months were terrible, there may be in place pieces of training and other things but those who have gone through some technical concepts, you have already done that.
# so "please see through before you dive in." Work life balance and good culture.
# Safe place to work, WFH opportunities during covid, on time salary payment, flexible timing n much more HCL is an Indian MNC and has clients globally and due to that there are chances to work for different clients, hence always there is an opportunity to learn and grow.
# Pros: Job security Open for learning Work life balance Free cabs Cons: No/micro annual hikes Micro management Office politics While leaving d company you have to pay hefty sum of amounts All trainings comes with a bond or agreements.
# Seniors, team leaders, managers as well as your co-workers are very helpful and cooperative, good for freshers to learn and built skills and to get exposure of corporate world, 5 days working, WFH during pandemic, company will provide systems /laptops to work on, both side cab facility, job training Only Job security is good here.
# Job security and work life balance will be awesome job security is good with HCL technologies.
# Work Culture is very good.
# Work life balance is good as WFH is prevalent.
# Recent times many managers are exhibiting disparity based on language, political views, castes which cannot be proved but daunting and stressful for employee being victimized HCL Technologies is one of the best MNC to work with In India, In my experience so far I have received lot of exposure in terms of my knowledge enhancement, work life balance, flexibility and having stability to work.
# There is nothing like on and off kind here, they provide the employee friendly environment to work, as a very secured job.
# Good learning, and skills developed, large campus, good job security in support functions, but for delivery/production functions consider it good until particular account margin grows Pros -Not much pressure ,learning opportunities Cons-Appraisals are bad and you will have to L the A for promotions otherwise promotion will be delayed and if you are going for promotion dont expect any hike in salary .
# Job security is there in hcl and they have lot of projects.
# HCL is company who is looking for work life balance.
# Overall good Company to work with.
# 1.I would like the work culture,project management especially Agile practice.i'm very proud to work with HCL as NPD Design Engineer.
# Good cafeteria and Gym. Wonderful company to work for.
# Over all it is good place to work unless you are looking for a huge salary hike.
# Never expect growth.Manager will never allow people to get good opportunity.Ratings are not done based on work.Lot of internal politics.policy will be changed by company for its own benefit.Will never rate employee based roles and responsibilities.Company good if you don't expect anything from your work about learning, growth, opportunity.
# Work culture is good also job is secure if you can handle the pressure and do complete your work.
# It's work culture is avg, management is helpful as of now.
# HCL company provides 100% job security and work life balance is the best part of the organization..

# %%
print(keywords.keywords(content))
# Out:
# work
# works
# worked
# management
# managers
# company
# job
# project
# hcl
# manager says
# employees
# employee
# developement companies
# salaries
# working interview weekend
# training
# trained
# trainings
# learning
# learned
# overall good experience
# time
# timing
# times
# timely
# engineering projects
# opportunities
# opportunity
# like
# liked
# salary differes
# team
# teams
# skilled
# skills
# skill
# learn new
# u
# years
# year
# yearly
# month
# monthly
# months
# appraisal
# appraisals
# based
# development
# developers
# develop
# developer
# developed
# policy
# policies
# great
# seniors
# ask
# asked
# asking
# asks
# provided
# provides
# provide
# providing
# culture
# cultural
# allowance
# allowed
# allow
# benefits
# balanced
# expectation
# expect
# expected
# expectations
# people
# leave benefit
# joined
# join
# joining
# technical growth
# pay
# paying
# secured
# security
# secure
# leaving
# leaves
# role
# roles
# politely
# politics
# political
# poor
# environment
# different
# client
# clients
# senior leads
# banking
# campus
# performed
# performance
# perform
# facility
# facilities
# tech
# annual
# annually
# life balance
# subjects
# subjected
# got
# bank related
# lot
# lots
# technically
# game
# gaming
# games
# grow
# grows
# thing
# things
# transport
# support
# supportive
# supported
# service
# services
# paid
# resource
# resources
# candidate
# candidates
# growing organization
# multiple
# b
# free
# period
# notice
# total
# totally
# engineer
# engineers
# place
# placed
# say
# saying
# hike
# hikes
# cafeteria
# ll
# r
# especially
# feel
# excellent
# excel
# design
# big cafeterias
# health
# leading
# lead
# away
# actually
# drive
# driving
# range
# ncr
# correct
# horrible
# customer
# customers
# weekends
# indian
# indians
# insurance
# help
# helpful
# helping
# required
# requirements
# requires
# compensation
# increment
# increments
# change
# changed
# net
# career
# careers
# rate
# ratings
# rating
# rated
# care
# cares
# sql
# worst
# stating
# architects
# architect
# terms
# term
# office
# pros
# quarterly
# quarter
# depends
# dependents
# tools
# incredibly
# incredible
# guard
# guards
# cab
# cabs
# friendly
# softwares
# software
# pressure
# human
# cleared
# clearing
# clearly
# facing
# face
# planning
# plan
# talk
# talks
# activities

# %%
summarizer.summarize(content, ratio=0.01)
# Out:
# "Not much growth in terms of skills you will be idle in most situations client is god for higher management Good company to start with but no great benefits are there if you are still in your 30s and are in need of a good package Company culture and word life balance is good but the compensation is not there Other companies do provide night shift allowance and pay on national holidays and festivals or at least provide gift to their employees but HCL do nothing like this just provide a comp off that's it that's something need to be changed You need to provide some strong reson to your employees to be in your company for longer period of time you have a job security here and can enjoy along with work as it has gym and games related options.\nSeniors, team leaders, managers as well as your co-workers are very helpful and cooperative, good for freshers to learn and built skills and to get exposure of corporate world, 5 days working, WFH during pandemic, company will provide systems /laptops to work on, both side cab facility, job training Only Job security is good here.\nNever expect growth.Manager will never allow people to get good opportunity.Ratings are not done based on work.Lot of internal politics.policy will be changed by company for its own benefit.Will never rate employee based roles and responsibilities.Company good if you don't expect anything from your work about learning, growth, opportunity."
