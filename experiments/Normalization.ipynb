# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('combinedReviews.csv')
df
# Out:
#        skillDevelopment                                         reviewText  \
# 0                   1.0       Its good and managable only because of team.
# 1                   4.0               Very balanced and rarely pressuring.
# 2                   3.0  working hours are 9:30 hours no shift allowanc...
# 3                   1.0  Too bad for a mid level experienced. Enquire p...
# 4                   1.0  Is there anything called work life balance her...
# ...                 ...                                                ...
# 97092               4.0  Work at wipro is good and you get opportunitie...
# 97093               4.0  The job is interested, struggle a bit in the t...
# 97094               3.0  Don’t know what to tell just want to say recog...
# 97095               4.0  Interesting and there are lots of learning opp...
# 97096               4.0                                                NaN
#
# ...

# %%
df_exhaustion=df[['workLifeBalance','companyCulture','workSatisfaction']]

# %%
df_ex=df_exhaustion.copy()

# %%
df_ex['exhaustion']=(0.35*df_exhaustion['workLifeBalance'])+(0.35*df_exhaustion['companyCulture'])+(0.30*df_exhaustion['workSatisfaction'])

# %%
df_ex
# Out:
#        workLifeBalance  companyCulture  workSatisfaction  exhaustion
# 0                  3.0             4.0               3.0        3.35
# 1                  5.0             3.0               4.0        4.00
# 2                  3.0             2.0               1.0        2.05
# 3                  2.0             1.0               1.0        1.35
# 4                  1.0             1.0               1.0        1.00
# ...                ...             ...               ...         ...
# 97092              5.0             4.0               4.0        4.35
# 97093              4.0             4.0               4.0        4.00
# 97094              2.0             3.0               3.0        2.65
# 97095              3.0             4.0               4.0        3.65
# 97096              4.0             4.0               4.0        4.00
#
# [97097 rows x 4 columns]

# %%
##Using z scores for normalization
df_exhaustion['exhaustion_normalized']=(df_ex['exhaustion'] - df_ex['exhaustion'].mean()) / df_ex['exhaustion'].std()
# Out:
# /var/folders/ng/wt_dfdlj1h1bcrnqngjm82v40000gn/T/ipykernel_4637/1350779357.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_exhaustion['exhaustion_normalized']=(df_ex['exhaustion'] - df_ex['exhaustion'].mean()) / df_ex['exhaustion'].std()

# %%
df_exhaustion
# Out:
#        workLifeBalance  companyCulture  workSatisfaction  \
# 0                  3.0             4.0               3.0
# 1                  5.0             3.0               4.0
# 2                  3.0             2.0               1.0
# 3                  2.0             1.0               1.0
# 4                  1.0             1.0               1.0
# ...                ...             ...               ...
# 97092              5.0             4.0               4.0
# 97093              4.0             4.0               4.0
# 97094              2.0             3.0               3.0
# 97095              3.0             4.0               4.0
# 97096              4.0             4.0               4.0
#
#        exhaustion_normalized
# 0                  -0.313184
# 1                   0.247800
# 2                  -1.435152
# 3                  -2.039289
# 4                  -2.341357
# ...                      ...
# 97092               0.549868
# 97093               0.247800
# ...

# %%
import pandas as pd
import numpy as np

def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
from sklearn.preprocessing import RobustScaler

# create a scaler object
scaler = RobustScaler()
df_robust=df_ex[['exhaustion']].copy()
# fit and transform the data
df_robust = pd.DataFrame(scaler.fit_transform(df_robust), columns=df_robust.columns)

df_robust
# Out:
#        exhaustion
# 0       -0.382353
# 1        0.000000
# 2       -1.147059
# 3       -1.558824
# 4       -1.764706
# ...           ...
# 97092    0.205882
# 97093    0.000000
# 97094   -0.794118
# 97095   -0.205882
# 97096    0.000000
#
# [97097 rows x 1 columns]
