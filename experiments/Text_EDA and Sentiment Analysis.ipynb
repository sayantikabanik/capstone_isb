# %% [markdown]
# ### Combining the review files

# %%
master_df = pd.DataFrame()

for file in os.listdir(os.getcwd()):
    if file.endswith('.csv'):
        master_df = master_df.append(pd.read_csv(file))
        
master_df.to_csv('Master File.csv', index=False)

# %%
master_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Reading the master file
df = pd.read_csv("C:/Users/Anindita/Documents/ISB/Capstone Project/Projects/Capstone Peak Health/Data/Master/Master.csv")

# %%
df.shape
# Out:
# (97097, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97097 entries, 0 to 97096
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   skillDevelopment  97006 non-null  float64
#  1   reviewText        43222 non-null  object
#  2   location          66513 non-null  object
#  3   cons              85931 non-null  object
#  4   salaryBenefits    96451 non-null  float64
#  5   workLifeBalance   97008 non-null  float64
#  6   pros              90430 non-null  object
#  7   workSatisfaction  96454 non-null  float64
#  8   postedon          97096 non-null  object
#  9   jobSecurity       96464 non-null  float64
#  10  careerGrowth      96446 non-null  float64
#  11  companyCulture    96473 non-null  float64
#  12  company           97096 non-null  object
#  13  jobFunction       96897 non-null  object
#  14  overallScore      97097 non-null  float64
# dtypes: float64(8), object(7)
# memory usage: 11.1+ MB

# %%
# Checking null values
df.isnull().sum()
# Out:
# skillDevelopment       91
# reviewText          53875
# location            30584
# cons                11166
# salaryBenefits        646
# workLifeBalance        89
# pros                 6667
# workSatisfaction      643
# postedon                1
# jobSecurity           633
# careerGrowth          651
# companyCulture        624
# company                 1
# jobFunction           200
# overallScore            0
# dtype: int64

# %% [markdown]
# #### We notice 55% of data missing under the column - ReviewText. However, the 'Pros' and 'Cons' columns have only ~ 7% and 11% data missing

# %%
# Extracting the desired variables for analysis
reviews = df[['company','overallScore','reviewText','cons','pros']]

# %%
reviews.shape
# Out:
# (97097, 5)

# %%
reviews.head()
# Out:
#             company  overallScore  \
# 0  HCL Technologies           1.0
# 1  HCL Technologies           4.0
# 2  HCL Technologies           3.0
# 3  HCL Technologies           1.0
# 4  HCL Technologies           1.0
#
#                                                                                             reviewText  \
# 0                                                         Its good and managable only because of team.
# 1                                                                 Very balanced and rarely pressuring.
# 2  working hours are 9:30 hours no shift allowances shift gets changed on weekly basis sometimes in...
# 3  Too bad for a mid level experienced. Enquire properly before joining the roles & responsibilitie...
# 4                             Is there anything called work life balance here!??..this colum is a joke
#
#                                                                                                   cons  \
# 0  Fake offers were given while recruiting. Wrong information about oppotunities were given. No tra...
# 1  * Although it's WFH as of now but no general transportation available. * Compensation & Hikes ar...
# 2  Management always listen what the manager saying there is no one listen for end user who is givi...
# 3  Work culture is too bad and experienced so many mind games and politics from the team mates. Ear...
# 4  Why not paying your employees good!? .Stop overloading them they have families too.Don't eat the...
#
#                                                                                                   pros
# 0  Only my collegues and work culture. There is no option to rate below 1 for compensation & benefi...
# 1  Overall good experience for me! Very much secured in terms of job security. Work life balance is...
# 2  Job security is there Client or Customer centric company and to make client or customer happy th...
# 3  It is a growing organization and has multiple mechanical engineering projects currently. Many of...
# 4  Hcl is avery good organization,But the middle management is shit. You wil get career growth if y...

# %%
reviews.groupby('company').size()
# Out:
# company
# HCL Technologies    17891
# Infosys             21639
# TCS                 36475
# Wipro               21091
# dtype: int64

# %%
# of reviews per company

plt.rcParams['figure.figsize'] = (15, 7)
sns.countplot(reviews['company'])
plt.title('No. of Reviews per Company', fontsize = 20)
# Out:
# C:\Users\Anindita\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'No. of Reviews per Company')

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97097 entries, 0 to 97096
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company       97096 non-null  object
#  1   overallScore  97097 non-null  float64
#  2   reviewText    43222 non-null  object
#  3   cons          85931 non-null  object
#  4   pros          90430 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 3.7+ MB

# %%
# Converting the textual data into string
reviews[['reviewText', 'cons', 'pros']] = reviews.loc[:, ['reviewText', 'cons', 'pros']]. astype(str) 
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97097 entries, 0 to 97096
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company       97096 non-null  object
#  1   overallScore  97097 non-null  float64
#  2   reviewText    97097 non-null  object
#  3   cons          97097 non-null  object
#  4   pros          97097 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 3.7+ MB

# %%
# Checking the row with 'nan' values
nan_in_col  = reviews[reviews['company'].isna()]
nan_in_col
# Out:
#       company  overallScore reviewText cons pros
# 39530     NaN      3.920606        nan  nan  nan

# %%
# Dropping the row with 'nan' values
reviews.dropna(axis = 0, how = 'any', inplace = True)
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97096 entries, 0 to 97096
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company       97096 non-null  object
#  1   overallScore  97096 non-null  float64
#  2   reviewText    97096 non-null  object
#  3   cons          97096 non-null  object
#  4   pros          97096 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 4.4+ MB

# %%
# Tokenization
reviews['tokenized_reviews'] = reviews['reviewText'].apply(word_tokenize)
reviews['tokenized_cons'] = reviews['cons'].apply(word_tokenize)
reviews['tokenized_pros'] = reviews['pros'].apply(word_tokenize)
reviews.head()
# Out:
#             company  overallScore  \
# 0  HCL Technologies           1.0
# 1  HCL Technologies           4.0
# 2  HCL Technologies           3.0
# 3  HCL Technologies           1.0
# 4  HCL Technologies           1.0
#
#                                                                                             reviewText  \
# 0                                                         Its good and managable only because of team.
# 1                                                                 Very balanced and rarely pressuring.
# 2  working hours are 9:30 hours no shift allowances shift gets changed on weekly basis sometimes in...
# 3  Too bad for a mid level experienced. Enquire properly before joining the roles & responsibilitie...
# 4                             Is there anything called work life balance here!??..this colum is a joke
#
#                                                                                                   cons  \
# 0  Fake offers were given while recruiting. Wrong information about oppotunities were given. No tra...
# 1  * Although it's WFH as of now but no general transportation available. * Compensation & Hikes ar...
# 2  Management always listen what the manager saying there is no one listen for end user who is givi...
# 3  Work culture is too bad and experienced so many mind games and politics from the team mates. Ear...
# 4  Why not paying your employees good!? .Stop overloading them they have families too.Don't eat the...
#
#                                                                                                   pros  \
# 0  Only my collegues and work culture. There is no option to rate below 1 for compensation & benefi...
# 1  Overall good experience for me! Very much secured in terms of job security. Work life balance is...
# 2  Job security is there Client or Customer centric company and to make client or customer happy th...
# 3  It is a growing organization and has multiple mechanical engineering projects currently. Many of...
# 4  Hcl is avery good organization,But the middle management is shit. You wil get career growth if y...
#
#                                                                                      tokenized_reviews  \
# 0                                              [Its, good, and, managable, only, because, of, team, .]
# 1                                                         [Very, balanced, and, rarely, pressuring, .]
# 2  [working, hours, are, 9:30, hours, no, shift, allowances, shift, gets, changed, on, weekly, basi...
# 3  [Too, bad, for, a, mid, level, experienced, ., Enquire, properly, before, joining, the, roles, &...
# 4      [Is, there, anything, called, work, life, balance, here, !, ?, ?, .., this, colum, is, a, joke]
#
#                                                                                         tokenized_cons  \
# 0  [Fake, offers, were, given, while, recruiting, ., Wrong, information, about, oppotunities, were,...
# 1  [*, Although, it, 's, WFH, as, of, now, but, no, general, transportation, available, ., *, Compe...
# 2  [Management, always, listen, what, the, manager, saying, there, is, no, one, listen, for, end, u...
# 3  [Work, culture, is, too, bad, and, experienced, so, many, mind, games, and, politics, from, the,...
# 4  [Why, not, paying, your, employees, good, !, ?, .Stop, overloading, them, they, have, families, ...
#
#                                                                                         tokenized_pros
# 0  [Only, my, collegues, and, work, culture, ., There, is, no, option, to, rate, below, 1, for, com...
# 1  [Overall, good, experience, for, me, !, Very, much, secured, in, terms, of, job, security, ., Wo...
# 2  [Job, security, is, there, Client, or, Customer, centric, company, and, to, make, client, or, cu...
# 3  [It, is, a, growing, organization, and, has, multiple, mechanical, engineering, projects, curren...
# 4  [Hcl, is, avery, good, organization, ,, But, the, middle, management, is, shit, ., You, wil, get...

# %%
# Converting to Lowercase
reviews['lower_reviews'] = reviews['tokenized_reviews'].apply(lambda x: [word.lower() for word in x])
reviews['lower_cons'] = reviews['tokenized_cons'].apply(lambda x: [word.lower() for word in x])
reviews['lower_pros'] = reviews['tokenized_pros'].apply(lambda x: [word.lower() for word in x])

# %%
# Removing Punctuations
punc = string.punctuation

reviews['nopunct_reviews'] = reviews['lower_reviews'].apply(lambda x: [word for word in x if word not in punc])
reviews['nopunct_cons'] = reviews['lower_cons'].apply(lambda x: [word for word in x if word not in punc])
reviews['nopunct_pros'] = reviews['lower_pros'].apply(lambda x: [word for word in x if word not in punc])

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Anindita\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Removal of Stopwords
stop_words = nltk.corpus.stopwords.words('english')
new_stopwords = ["tcs","infosys","hcl","wipro", "nan"]
stop_words.extend(new_stopwords)

# %%
reviews['reviewText_clean'] = reviews['nopunct_reviews'].apply(lambda x: [word for word in x if word not in stop_words])
reviews['cons_clean'] = reviews['nopunct_cons'].apply(lambda x: [word for word in x if word not in stop_words])
reviews['pros_clean'] = reviews['nopunct_pros'].apply(lambda x: [word for word in x if word not in stop_words])

reviews['reviewText_str'] = [' '.join(map(str,l)) for l in reviews['reviewText_clean']]
reviews['cons_str'] = [' '.join(map(str,l)) for l in reviews['cons_clean']]
reviews['pros_str'] = [' '.join(map(str,l)) for l in reviews['pros_clean']]

reviews.head()
# Out:
#             company  overallScore  \
# 0  HCL Technologies           1.0
# 1  HCL Technologies           4.0
# 2  HCL Technologies           3.0
# 3  HCL Technologies           1.0
# 4  HCL Technologies           1.0
#
#                                                                                             reviewText  \
# 0                                                         Its good and managable only because of team.
# 1                                                                 Very balanced and rarely pressuring.
# 2  working hours are 9:30 hours no shift allowances shift gets changed on weekly basis sometimes in...
# 3  Too bad for a mid level experienced. Enquire properly before joining the roles & responsibilitie...
# 4                             Is there anything called work life balance here!??..this colum is a joke
#
#                                                                                                   cons  \
# 0  Fake offers were given while recruiting. Wrong information about oppotunities were given. No tra...
# 1  * Although it's WFH as of now but no general transportation available. * Compensation & Hikes ar...
# 2  Management always listen what the manager saying there is no one listen for end user who is givi...
# 3  Work culture is too bad and experienced so many mind games and politics from the team mates. Ear...
# 4  Why not paying your employees good!? .Stop overloading them they have families too.Don't eat the...
#
#                                                                                                   pros  \
# 0  Only my collegues and work culture. There is no option to rate below 1 for compensation & benefi...
# 1  Overall good experience for me! Very much secured in terms of job security. Work life balance is...
# 2  Job security is there Client or Customer centric company and to make client or customer happy th...
# 3  It is a growing organization and has multiple mechanical engineering projects currently. Many of...
# 4  Hcl is avery good organization,But the middle management is shit. You wil get career growth if y...
#
#                                                                                      tokenized_reviews  \
# 0                                              [Its, good, and, managable, only, because, of, team, .]
# 1                                                         [Very, balanced, and, rarely, pressuring, .]
# 2  [working, hours, are, 9:30, hours, no, shift, allowances, shift, gets, changed, on, weekly, basi...
# 3  [Too, bad, for, a, mid, level, experienced, ., Enquire, properly, before, joining, the, roles, &...
# 4      [Is, there, anything, called, work, life, balance, here, !, ?, ?, .., this, colum, is, a, joke]
#
#                                                                                         tokenized_cons  \
# 0  [Fake, offers, were, given, while, recruiting, ., Wrong, information, about, oppotunities, were,...
# 1  [*, Although, it, 's, WFH, as, of, now, but, no, general, transportation, available, ., *, Compe...
# 2  [Management, always, listen, what, the, manager, saying, there, is, no, one, listen, for, end, u...
# 3  [Work, culture, is, too, bad, and, experienced, so, many, mind, games, and, politics, from, the,...
# 4  [Why, not, paying, your, employees, good, !, ?, .Stop, overloading, them, they, have, families, ...
#
#                                                                                         tokenized_pros  \
# 0  [Only, my, collegues, and, work, culture, ., There, is, no, option, to, rate, below, 1, for, com...
# 1  [Overall, good, experience, for, me, !, Very, much, secured, in, terms, of, job, security, ., Wo...
# 2  [Job, security, is, there, Client, or, Customer, centric, company, and, to, make, client, or, cu...
# 3  [It, is, a, growing, organization, and, has, multiple, mechanical, engineering, projects, curren...
# 4  [Hcl, is, avery, good, organization, ,, But, the, middle, management, is, shit, ., You, wil, get...
#
#                                                                                          lower_reviews  \
# 0                                              [its, good, and, managable, only, because, of, team, .]
# 1                                                         [very, balanced, and, rarely, pressuring, .]
# 2  [working, hours, are, 9:30, hours, no, shift, allowances, shift, gets, changed, on, weekly, basi...
# 3  [too, bad, for, a, mid, level, experienced, ., enquire, properly, before, joining, the, roles, &...
# 4      [is, there, anything, called, work, life, balance, here, !, ?, ?, .., this, colum, is, a, joke]
#
#                                                                                             lower_cons  \
# 0  [fake, offers, were, given, while, recruiting, ., wrong, information, about, oppotunities, were,...
# 1  [*, although, it, 's, wfh, as, of, now, but, no, general, transportation, available, ., *, compe...
# 2  [management, always, listen, what, the, manager, saying, there, is, no, one, listen, for, end, u...
# 3  [work, culture, is, too, bad, and, experienced, so, many, mind, games, and, politics, from, the,...
# 4  [why, not, paying, your, employees, good, !, ?, .stop, overloading, them, they, have, families, ...
#
#                                                                                             lower_pros  \
# 0  [only, my, collegues, and, work, culture, ., there, is, no, option, to, rate, below, 1, for, com...
# 1  [overall, good, experience, for, me, !, very, much, secured, in, terms, of, job, security, ., wo...
# 2  [job, security, is, there, client, or, customer, centric, company, and, to, make, client, or, cu...
# 3  [it, is, a, growing, organization, and, has, multiple, mechanical, engineering, projects, curren...
# 4  [hcl, is, avery, good, organization, ,, but, the, middle, management, is, shit, ., you, wil, get...
#
#                                                                                        nopunct_reviews  \
# 0                                                 [its, good, and, managable, only, because, of, team]
# 1                                                            [very, balanced, and, rarely, pressuring]
# 2  [working, hours, are, 9:30, hours, no, shift, allowances, shift, gets, changed, on, weekly, basi...
# 3  [too, bad, for, a, mid, level, experienced, enquire, properly, before, joining, the, roles, resp...
# 4               [is, there, anything, called, work, life, balance, here, .., this, colum, is, a, joke]
#
#                                                                                           nopunct_cons  \
# 0  [fake, offers, were, given, while, recruiting, wrong, information, about, oppotunities, were, gi...
# 1  [although, it, 's, wfh, as, of, now, but, no, general, transportation, available, compensation, ...
# 2  [management, always, listen, what, the, manager, saying, there, is, no, one, listen, for, end, u...
# 3  [work, culture, is, too, bad, and, experienced, so, many, mind, games, and, politics, from, the,...
# 4  [why, not, paying, your, employees, good, .stop, overloading, them, they, have, families, too.do...
#
#                                                                                           nopunct_pros  \
# 0  [only, my, collegues, and, work, culture, there, is, no, option, to, rate, below, 1, for, compen...
# 1  [overall, good, experience, for, me, very, much, secured, in, terms, of, job, security, work, li...
# 2  [job, security, is, there, client, or, customer, centric, company, and, to, make, client, or, cu...
# 3  [it, is, a, growing, organization, and, has, multiple, mechanical, engineering, projects, curren...
# 4  [hcl, is, avery, good, organization, but, the, middle, management, is, shit, you, wil, get, care...
#
#                                                                                       reviewText_clean  \
# 0                                                                              [good, managable, team]
# 1                                                                       [balanced, rarely, pressuring]
# 2  [working, hours, 9:30, hours, shift, allowances, shift, gets, changed, weekly, basis, sometimes,...
# 3  [bad, mid, level, experienced, enquire, properly, joining, roles, responsibilities, close, circl...
# 4                                             [anything, called, work, life, balance, .., colum, joke]
#
#                                                                                             cons_clean  \
# 0  [fake, offers, given, recruiting, wrong, information, oppotunities, given, transparency, equalit...
# 1  [although, 's, wfh, general, transportation, available, compensation, hikes, per, market, standa...
# 2  [management, always, listen, manager, saying, one, listen, end, user, giving, life, time, making...
# 3  [work, culture, bad, experienced, many, mind, games, politics, team, mates, earlier, 2010, 2013,...
# 4  [paying, employees, good, .stop, overloading, families, too.do, n't, eat, money.also, people, aw...
#
#                                                                                             pros_clean  \
# 0  [collegues, work, culture, option, rate, 1, compensation, benefits, job, oppotunities, otherwise...
# 1  [overall, good, experience, much, secured, terms, job, security, work, life, balance, per, expec...
# 2  [job, security, client, customer, centric, company, make, client, customer, happy, forgot, engin...
# 3  [growing, organization, multiple, mechanical, engineering, projects, currently, many, team, size...
# 4  [avery, good, organization, middle, management, shit, wil, get, career, growth, joined, internal...
#
#                                                                                         reviewText_str  \
# 0                                                                                  good managable team
# 1                                                                           balanced rarely pressuring
# 2  working hours 9:30 hours shift allowances shift gets changed weekly basis sometimes week 2 days ...
# 3  bad mid level experienced enquire properly joining roles responsibilities close circle hr interv...
# 4                                                      anything called work life balance .. colum joke
#
#                                                                                               cons_str  \
# 0  fake offers given recruiting wrong information oppotunities given transparency equality favourit...
# 1  although 's wfh general transportation available compensation hikes per market standards promoti...
# 2  management always listen manager saying one listen end user giving life time making company crit...
# 3  work culture bad experienced many mind games politics team mates earlier 2010 2013 company cultu...
# 4  paying employees good .stop overloading families too.do n't eat money.also people aware fact dif...
#
#                                                                                               pros_str
# 0  collegues work culture option rate 1 compensation benefits job oppotunities otherwise could give...
# 1  overall good experience much secured terms job security work life balance per expectation wfh te...
# 2  job security client customer centric company make client customer happy forgot engineer manageme...
# 3  growing organization multiple mechanical engineering projects currently many team size grow rapi...
# 4  avery good organization middle management shit wil get career growth joined internal projects.if...

# %% [markdown]
# ### Generating Word Cloud

# %%
def plot_wordcloud(docx):
    mywordcloud = WordCloud(width=1600, height=800, background_color='white',max_words=100).generate(docx)
    fig = plt.figure(figsize=(30,10), facecolor='white')
    plt.imshow(mywordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.title('Top 100 Words', fontsize=100)
    plt.show()

# %%
all_docx = ' '.join(reviews['reviewText_str'])
plot_wordcloud(all_docx)

# %%
# TCS' summary

plt.rcParams['figure.figsize'] = (18, 10)

pros = ' '.join([text for text in reviews['pros_str'][reviews['company'] == 'TCS']])

wordcloud = WordCloud(background_color = 'white', width = 1200, height = 1200, max_words=50).generate(pros)
plt.subplot(1, 2, 1)
plt.title('TCS-Pros', fontsize = 20)
plt.imshow(wordcloud)
plt.axis('off')

cons = ' '.join([text for text in reviews['cons_str'][reviews['company'] == 'TCS']])

wordcloud2 = WordCloud(background_color = 'white', width = 1200, height = 1200, max_words=50).generate(cons)
plt.subplot(1, 2, 2)
plt.title('TCS-Cons', fontsize = 20)
plt.imshow(wordcloud2)
plt.axis('off')
# Out:
# (-0.5, 1199.5, 1199.5, -0.5)

# %%
# Infosys' summary

plt.rcParams['figure.figsize'] = (18, 10)

pros = ' '.join([text for text in reviews['pros_str'][reviews['company'] == 'Infosys']])

wordcloud = WordCloud(background_color = 'white', width = 1200, height = 1200, max_words=50).generate(pros)
plt.subplot(1, 2, 1)
plt.title('Infosys-Pros', fontsize = 20)
plt.imshow(wordcloud)
plt.axis('off')

cons = ' '.join([text for text in reviews['cons_str'][reviews['company'] == 'Infosys']])

wordcloud2 = WordCloud(background_color = 'white', width = 1200, height = 1200, max_words=50).generate(cons)
plt.subplot(1, 2, 2)
plt.title('Infosys-Cons', fontsize = 20)
plt.imshow(wordcloud2)
plt.axis('off')
# Out:
# (-0.5, 1199.5, 1199.5, -0.5)

# %%
# Wipro summary

plt.rcParams['figure.figsize'] = (18, 10)

pros = ' '.join([text for text in reviews['pros_str'][reviews['company'] == 'Wipro']])

wordcloud = WordCloud(background_color = 'white', width = 1200, height = 1200, max_words=50).generate(pros)
plt.subplot(1, 2, 1)
plt.title('Wipro-Pros', fontsize = 20)
plt.imshow(wordcloud)
plt.axis('off')

cons = ' '.join([text for text in reviews['cons_str'][reviews['company'] == 'Wipro']])

wordcloud2 = WordCloud(background_color = 'white', width = 1200, height = 1200, max_words=50).generate(cons)
plt.subplot(1, 2, 2)
plt.title('Wipro-Cons', fontsize = 20)
plt.imshow(wordcloud2)
plt.axis('off')
# Out:
# (-0.5, 1199.5, 1199.5, -0.5)

# %%
# HCL Technologies' summary

plt.rcParams['figure.figsize'] = (18, 10)

pros = ' '.join([text for text in reviews['pros_str'][reviews['company'] == 'HCL Technologies']])

wordcloud = WordCloud(background_color = 'white', width = 1200, height = 1200, max_words=50).generate(pros)
plt.subplot(1, 2, 1)
plt.title('HCL-Pros', fontsize = 20)
plt.imshow(wordcloud)
plt.axis('off')

cons = ' '.join([text for text in reviews['cons_str'][reviews['company'] == 'HCL Technologies']])

wordcloud2 = WordCloud(background_color = 'white', width = 1200, height = 1200, max_words=50).generate(cons)
plt.subplot(1, 2, 2)
plt.title('HCL-Cons', fontsize = 20)
plt.imshow(wordcloud2)
plt.axis('off')
# Out:
# (-0.5, 1199.5, 1199.5, -0.5)

# %%
reviews.to_csv('reviews_clean.csv')

# %%
# Extracting the desired variables for analysis
clean = reviews.loc[:, ['company','overallScore','reviewText_clean']]

# %%
# Lemmatization
clean['pos_tags'] = clean['reviewText_clean'].apply(nltk.tag.pos_tag)
clean.head()
# Out:
#             company  overallScore  \
# 0  HCL Technologies           1.0
# 1  HCL Technologies           4.0
# 2  HCL Technologies           3.0
# 3  HCL Technologies           1.0
# 4  HCL Technologies           1.0
#
#                                                                                       reviewText_clean  \
# 0                                                                              [good, managable, team]
# 1                                                                       [balanced, rarely, pressuring]
# 2  [working, hours, 9:30, hours, shift, allowances, shift, gets, changed, weekly, basis, sometimes,...
# 3  [bad, mid, level, experienced, enquire, properly, joining, roles, responsibilities, close, circl...
# 4                                             [anything, called, work, life, balance, .., colum, joke]
#
#                                                                                               pos_tags
# 0                                                            [(good, JJ), (managable, JJ), (team, NN)]
# 1                                                   [(balanced, VBN), (rarely, RB), (pressuring, VBG)]
# 2  [(working, VBG), (hours, NNS), (9:30, CD), (hours, NNS), (shift, JJ), (allowances, NNS), (shift,...
# 3  [(bad, JJ), (mid, NNS), (level, NN), (experienced, VBD), (enquire, RB), (properly, JJ), (joining...
# 4  [(anything, NN), (called, VBN), (work, NN), (life, NN), (balance, NN), (.., NNP), (colum, NN), (...

# %%
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN
clean['wordnet_pos'] = clean['pos_tags'].apply(lambda x: [(word, get_wordnet_pos(pos_tag)) for (word, pos_tag) in x])
clean.head()
# Out:
#             company  overallScore  \
# 0  HCL Technologies           1.0
# 1  HCL Technologies           4.0
# 2  HCL Technologies           3.0
# 3  HCL Technologies           1.0
# 4  HCL Technologies           1.0
#
#                                                                                       reviewText_clean  \
# 0                                                                              [good, managable, team]
# 1                                                                       [balanced, rarely, pressuring]
# 2  [working, hours, 9:30, hours, shift, allowances, shift, gets, changed, weekly, basis, sometimes,...
# 3  [bad, mid, level, experienced, enquire, properly, joining, roles, responsibilities, close, circl...
# 4                                             [anything, called, work, life, balance, .., colum, joke]
#
#                                                                                               pos_tags  \
# 0                                                            [(good, JJ), (managable, JJ), (team, NN)]
# 1                                                   [(balanced, VBN), (rarely, RB), (pressuring, VBG)]
# 2  [(working, VBG), (hours, NNS), (9:30, CD), (hours, NNS), (shift, JJ), (allowances, NNS), (shift,...
# 3  [(bad, JJ), (mid, NNS), (level, NN), (experienced, VBD), (enquire, RB), (properly, JJ), (joining...
# 4  [(anything, NN), (called, VBN), (work, NN), (life, NN), (balance, NN), (.., NNP), (colum, NN), (...
#
#                                                                                            wordnet_pos
# 0                                                               [(good, a), (managable, a), (team, n)]
# 1                                                        [(balanced, v), (rarely, r), (pressuring, v)]
# 2  [(working, v), (hours, n), (9:30, n), (hours, n), (shift, a), (allowances, n), (shift, a), (gets...
# 3  [(bad, a), (mid, n), (level, n), (experienced, v), (enquire, r), (properly, a), (joining, v), (r...
# 4     [(anything, n), (called, v), (work, n), (life, n), (balance, n), (.., n), (colum, n), (joke, n)]

# %%
wnl = WordNetLemmatizer()
clean['lemmatized'] = clean['wordnet_pos'].apply(lambda x: [wnl.lemmatize(word, tag) for word, tag in x])
clean.head()
# Out:
#             company  overallScore  \
# 0  HCL Technologies           1.0
# 1  HCL Technologies           4.0
# 2  HCL Technologies           3.0
# 3  HCL Technologies           1.0
# 4  HCL Technologies           1.0
#
#                                                                                       reviewText_clean  \
# 0                                                                              [good, managable, team]
# 1                                                                       [balanced, rarely, pressuring]
# 2  [working, hours, 9:30, hours, shift, allowances, shift, gets, changed, weekly, basis, sometimes,...
# 3  [bad, mid, level, experienced, enquire, properly, joining, roles, responsibilities, close, circl...
# 4                                             [anything, called, work, life, balance, .., colum, joke]
#
#                                                                                               pos_tags  \
# 0                                                            [(good, JJ), (managable, JJ), (team, NN)]
# 1                                                   [(balanced, VBN), (rarely, RB), (pressuring, VBG)]
# 2  [(working, VBG), (hours, NNS), (9:30, CD), (hours, NNS), (shift, JJ), (allowances, NNS), (shift,...
# 3  [(bad, JJ), (mid, NNS), (level, NN), (experienced, VBD), (enquire, RB), (properly, JJ), (joining...
# 4  [(anything, NN), (called, VBN), (work, NN), (life, NN), (balance, NN), (.., NNP), (colum, NN), (...
#
#                                                                                            wordnet_pos  \
# 0                                                               [(good, a), (managable, a), (team, n)]
# 1                                                        [(balanced, v), (rarely, r), (pressuring, v)]
# 2  [(working, v), (hours, n), (9:30, n), (hours, n), (shift, a), (allowances, n), (shift, a), (gets...
# 3  [(bad, a), (mid, n), (level, n), (experienced, v), (enquire, r), (properly, a), (joining, v), (r...
# 4     [(anything, n), (called, v), (work, n), (life, n), (balance, n), (.., n), (colum, n), (joke, n)]
#
#                                                                                             lemmatized
# 0                                                                              [good, managable, team]
# 1                                                                          [balance, rarely, pressure]
# 2  [work, hour, 9:30, hour, shift, allowance, shift, get, changed, weekly, basis, sometimes, week, ...
# 3  [bad, mid, level, experience, enquire, properly, join, role, responsibility, close, circle, hr, ...
# 4                                               [anything, call, work, life, balance, .., colum, joke]

# %%
# Importing Libraries
import pyLDAvis.sklearn
from collections import Counter
from textblob import TextBlob
from nltk.probability import FreqDist
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation, NMF
from wordcloud import WordCloud, ImageColorGenerator

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
clean['lemma_str'] = [' '.join(map(str,l)) for l in clean['lemmatized']]
clean.head()
# Out:
#             company  overallScore  \
# 0  HCL Technologies           1.0
# 1  HCL Technologies           4.0
# 2  HCL Technologies           3.0
# 3  HCL Technologies           1.0
# 4  HCL Technologies           1.0
#
#                                                                                       reviewText_clean  \
# 0                                                                              [good, managable, team]
# 1                                                                       [balanced, rarely, pressuring]
# 2  [working, hours, 9:30, hours, shift, allowances, shift, gets, changed, weekly, basis, sometimes,...
# 3  [bad, mid, level, experienced, enquire, properly, joining, roles, responsibilities, close, circl...
# 4                                             [anything, called, work, life, balance, .., colum, joke]
#
#                                                                                               pos_tags  \
# 0                                                            [(good, JJ), (managable, JJ), (team, NN)]
# 1                                                   [(balanced, VBN), (rarely, RB), (pressuring, VBG)]
# 2  [(working, VBG), (hours, NNS), (9:30, CD), (hours, NNS), (shift, JJ), (allowances, NNS), (shift,...
# 3  [(bad, JJ), (mid, NNS), (level, NN), (experienced, VBD), (enquire, RB), (properly, JJ), (joining...
# 4  [(anything, NN), (called, VBN), (work, NN), (life, NN), (balance, NN), (.., NNP), (colum, NN), (...
#
#                                                                                            wordnet_pos  \
# 0                                                               [(good, a), (managable, a), (team, n)]
# 1                                                        [(balanced, v), (rarely, r), (pressuring, v)]
# 2  [(working, v), (hours, n), (9:30, n), (hours, n), (shift, a), (allowances, n), (shift, a), (gets...
# 3  [(bad, a), (mid, n), (level, n), (experienced, v), (enquire, r), (properly, a), (joining, v), (r...
# 4     [(anything, n), (called, v), (work, n), (life, n), (balance, n), (.., n), (colum, n), (joke, n)]
#
#                                                                                             lemmatized  \
# 0                                                                              [good, managable, team]
# 1                                                                          [balance, rarely, pressure]
# 2  [work, hour, 9:30, hour, shift, allowance, shift, get, changed, weekly, basis, sometimes, week, ...
# 3  [bad, mid, level, experience, enquire, properly, join, role, responsibility, close, circle, hr, ...
# 4                                               [anything, call, work, life, balance, .., colum, joke]
#
#                                                                                              lemma_str
# 0                                                                                  good managable team
# 1                                                                              balance rarely pressure
# 2  work hour 9:30 hour shift allowance shift get changed weekly basis sometimes week 2 day morning ...
# 3  bad mid level experience enquire properly join role responsibility close circle hr interviewer w...
# 4                                                        anything call work life balance .. colum joke

# %% [markdown]
# ### Sentiment Analysis using TextBlob

# %%
from textblob import TextBlob

def get_sentiment(text):
    blob = TextBlob(text)
    sentiment_polarity = blob.sentiment.polarity
    sentiment_subjectivity = blob.sentiment.subjectivity
    if sentiment_polarity > 0:
        sentiment_label = 'Positive'
    elif sentiment_polarity < 0:
        sentiment_label = 'Negative'
    else:
        sentiment_label = 'Neutral'
    result = {'polarity_blob':sentiment_polarity,
              'subjectivity_blob':sentiment_subjectivity,
              'sentiment_blob':sentiment_label}
    return result

# %%
clean['sentiment_results'] = clean['lemma_str'].apply(get_sentiment)

# %%
clean = clean.join(pd.json_normalize(clean['sentiment_results']))
clean.head()
# Out:
#             company  overallScore  \
# 0  HCL Technologies           1.0
# 1  HCL Technologies           4.0
# 2  HCL Technologies           3.0
# 3  HCL Technologies           1.0
# 4  HCL Technologies           1.0
#
#                                                                                       reviewText_clean  \
# 0                                                                              [good, managable, team]
# 1                                                                       [balanced, rarely, pressuring]
# 2  [working, hours, 9:30, hours, shift, allowances, shift, gets, changed, weekly, basis, sometimes,...
# 3  [bad, mid, level, experienced, enquire, properly, joining, roles, responsibilities, close, circl...
# 4                                             [anything, called, work, life, balance, .., colum, joke]
#
#                                                                                               pos_tags  \
# 0                                                            [(good, JJ), (managable, JJ), (team, NN)]
# 1                                                   [(balanced, VBN), (rarely, RB), (pressuring, VBG)]
# 2  [(working, VBG), (hours, NNS), (9:30, CD), (hours, NNS), (shift, JJ), (allowances, NNS), (shift,...
# 3  [(bad, JJ), (mid, NNS), (level, NN), (experienced, VBD), (enquire, RB), (properly, JJ), (joining...
# 4  [(anything, NN), (called, VBN), (work, NN), (life, NN), (balance, NN), (.., NNP), (colum, NN), (...
#
#                                                                                            wordnet_pos  \
# 0                                                               [(good, a), (managable, a), (team, n)]
# 1                                                        [(balanced, v), (rarely, r), (pressuring, v)]
# 2  [(working, v), (hours, n), (9:30, n), (hours, n), (shift, a), (allowances, n), (shift, a), (gets...
# 3  [(bad, a), (mid, n), (level, n), (experienced, v), (enquire, r), (properly, a), (joining, v), (r...
# 4     [(anything, n), (called, v), (work, n), (life, n), (balance, n), (.., n), (colum, n), (joke, n)]
#
#                                                                                             lemmatized  \
# 0                                                                              [good, managable, team]
# 1                                                                          [balance, rarely, pressure]
# 2  [work, hour, 9:30, hour, shift, allowance, shift, get, changed, weekly, basis, sometimes, week, ...
# 3  [bad, mid, level, experience, enquire, properly, join, role, responsibility, close, circle, hr, ...
# 4                                               [anything, call, work, life, balance, .., colum, joke]
#
#                                                                                              lemma_str  \
# 0                                                                                  good managable team
# 1                                                                              balance rarely pressure
# 2  work hour 9:30 hour shift allowance shift get changed weekly basis sometimes week 2 day morning ...
# 3  bad mid level experience enquire properly join role responsibility close circle hr interviewer w...
# 4                                                        anything call work life balance .. colum joke
#
#                                                                                      sentiment_results  \
# 0        {'polarity_blob': 0.7, 'subjectivity_blob': 0.6000000000000001, 'sentiment_blob': 'Positive'}
# 1                       {'polarity_blob': 0.3, 'subjectivity_blob': 0.9, 'sentiment_blob': 'Positive'}
# 2  {'polarity_blob': -0.24999999999999997, 'subjectivity_blob': 0.2611111111111111, 'sentiment_blob...
# 3  {'polarity_blob': -0.11249999999999996, 'subjectivity_blob': 0.25416666666666665, 'sentiment_blo...
# 4                        {'polarity_blob': 0.0, 'subjectivity_blob': 0.0, 'sentiment_blob': 'Neutral'}
#
#    polarity_blob  subjectivity_blob sentiment_blob
# 0         0.7000           0.600000       Positive
# 1         0.3000           0.900000       Positive
# 2        -0.2500           0.261111       Negative
# 3        -0.1125           0.254167       Negative
# 4         0.0000           0.000000        Neutral

# %%
plt.figure(figsize=(50,30))
sns.histplot(data=clean, x="overallScore", color="skyblue", label="Overall Rating Score", kde=True)
sns.histplot(data=clean, x="polarity_blob", color="red", label="Sentiment Distribution", kde=True)

plt.legend() 
plt.show()

# %%
plt.figure(figsize=(50,30))
plt.margins(0.02)
plt.xlabel('Sentiment', fontsize=50)
plt.xticks(fontsize=40)
plt.ylabel('Frequency', fontsize=50)
plt.yticks(fontsize=40)
plt.hist(clean['polarity_blob'], bins=50)
plt.title('Sentiment Distribution', fontsize=60)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (18, 10)

sns.displot(clean, x="polarity_blob", col="company")

# %%
sns.countplot(clean['sentiment_blob'])
# Out:
# C:\Users\Anindita\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sentiment_blob', ylabel='count'>

# %%
sns.countplot(y ='company', hue = 'sentiment_blob', data = clean)
# Out:
# <AxesSubplot:xlabel='count', ylabel='company'>

# %% [markdown]
# ### Sentiment Analysis using VADER

# %%
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Anindita\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
clean['scores_vader'] = clean['lemma_str'].apply(lambda lemma_str: sid.polarity_scores(lemma_str))
clean.head()
# Out:
#             company  overallScore  \
# 0  HCL Technologies           1.0
# 1  HCL Technologies           4.0
# 2  HCL Technologies           3.0
# 3  HCL Technologies           1.0
# 4  HCL Technologies           1.0
#
#                                                                                       reviewText_clean  \
# 0                                                                              [good, managable, team]
# 1                                                                       [balanced, rarely, pressuring]
# 2  [working, hours, 9:30, hours, shift, allowances, shift, gets, changed, weekly, basis, sometimes,...
# 3  [bad, mid, level, experienced, enquire, properly, joining, roles, responsibilities, close, circl...
# 4                                             [anything, called, work, life, balance, .., colum, joke]
#
#                                                                                               pos_tags  \
# 0                                                            [(good, JJ), (managable, JJ), (team, NN)]
# 1                                                   [(balanced, VBN), (rarely, RB), (pressuring, VBG)]
# 2  [(working, VBG), (hours, NNS), (9:30, CD), (hours, NNS), (shift, JJ), (allowances, NNS), (shift,...
# 3  [(bad, JJ), (mid, NNS), (level, NN), (experienced, VBD), (enquire, RB), (properly, JJ), (joining...
# 4  [(anything, NN), (called, VBN), (work, NN), (life, NN), (balance, NN), (.., NNP), (colum, NN), (...
#
#                                                                                            wordnet_pos  \
# 0                                                               [(good, a), (managable, a), (team, n)]
# 1                                                        [(balanced, v), (rarely, r), (pressuring, v)]
# 2  [(working, v), (hours, n), (9:30, n), (hours, n), (shift, a), (allowances, n), (shift, a), (gets...
# 3  [(bad, a), (mid, n), (level, n), (experienced, v), (enquire, r), (properly, a), (joining, v), (r...
# 4     [(anything, n), (called, v), (work, n), (life, n), (balance, n), (.., n), (colum, n), (joke, n)]
#
#                                                                                             lemmatized  \
# 0                                                                              [good, managable, team]
# 1                                                                          [balance, rarely, pressure]
# 2  [work, hour, 9:30, hour, shift, allowance, shift, get, changed, weekly, basis, sometimes, week, ...
# 3  [bad, mid, level, experience, enquire, properly, join, role, responsibility, close, circle, hr, ...
# 4                                               [anything, call, work, life, balance, .., colum, joke]
#
#                                                                                              lemma_str  \
# 0                                                                                  good managable team
# 1                                                                              balance rarely pressure
# 2  work hour 9:30 hour shift allowance shift get changed weekly basis sometimes week 2 day morning ...
# 3  bad mid level experience enquire properly join role responsibility close circle hr interviewer w...
# 4                                                        anything call work life balance .. colum joke
#
#                                                                                      sentiment_results  \
# 0        {'polarity_blob': 0.7, 'subjectivity_blob': 0.6000000000000001, 'sentiment_blob': 'Positive'}
# 1                       {'polarity_blob': 0.3, 'subjectivity_blob': 0.9, 'sentiment_blob': 'Positive'}
# 2  {'polarity_blob': -0.24999999999999997, 'subjectivity_blob': 0.2611111111111111, 'sentiment_blob...
# 3  {'polarity_blob': -0.11249999999999996, 'subjectivity_blob': 0.25416666666666665, 'sentiment_blo...
# 4                        {'polarity_blob': 0.0, 'subjectivity_blob': 0.0, 'sentiment_blob': 'Neutral'}
#
#    polarity_blob  subjectivity_blob sentiment_blob  \
# 0         0.7000           0.600000       Positive
# 1         0.3000           0.900000       Positive
# 2        -0.2500           0.261111       Negative
# 3        -0.1125           0.254167       Negative
# 4         0.0000           0.000000        Neutral
#
#                                                       scores_vader
# 0     {'neg': 0.0, 'neu': 0.408, 'pos': 0.592, 'compound': 0.4404}
# 1     {'neg': 0.0, 'neu': 0.514, 'pos': 0.486, 'compound': 0.2235}
# 2  {'neg': 0.114, 'neu': 0.844, 'pos': 0.042, 'compound': -0.4939}
# 3  {'neg': 0.136, 'neu': 0.778, 'pos': 0.086, 'compound': -0.3182}
# 4      {'neg': 0.0, 'neu': 0.761, 'pos': 0.239, 'compound': 0.296}

# %%
clean['compound_vader'] = clean['scores_vader'].apply(lambda score_dict: score_dict['compound'])
clean['sentiment_vader']=''
clean.loc[clean.compound_vader>0,'sentiment_vader']='Positive'
clean.loc[clean.compound_vader==0,'sentiment_vader']='Neutral'
clean.loc[clean.compound_vader<0,'sentiment_vader']='Negative'

# %%
clean.head()
# Out:
#             company  overallScore  \
# 0  HCL Technologies           1.0
# 1  HCL Technologies           4.0
# 2  HCL Technologies           3.0
# 3  HCL Technologies           1.0
# 4  HCL Technologies           1.0
#
#                                                                                       reviewText_clean  \
# 0                                                                              [good, managable, team]
# 1                                                                       [balanced, rarely, pressuring]
# 2  [working, hours, 9:30, hours, shift, allowances, shift, gets, changed, weekly, basis, sometimes,...
# 3  [bad, mid, level, experienced, enquire, properly, joining, roles, responsibilities, close, circl...
# 4                                             [anything, called, work, life, balance, .., colum, joke]
#
#                                                                                               pos_tags  \
# 0                                                            [(good, JJ), (managable, JJ), (team, NN)]
# 1                                                   [(balanced, VBN), (rarely, RB), (pressuring, VBG)]
# 2  [(working, VBG), (hours, NNS), (9:30, CD), (hours, NNS), (shift, JJ), (allowances, NNS), (shift,...
# 3  [(bad, JJ), (mid, NNS), (level, NN), (experienced, VBD), (enquire, RB), (properly, JJ), (joining...
# 4  [(anything, NN), (called, VBN), (work, NN), (life, NN), (balance, NN), (.., NNP), (colum, NN), (...
#
#                                                                                            wordnet_pos  \
# 0                                                               [(good, a), (managable, a), (team, n)]
# 1                                                        [(balanced, v), (rarely, r), (pressuring, v)]
# 2  [(working, v), (hours, n), (9:30, n), (hours, n), (shift, a), (allowances, n), (shift, a), (gets...
# 3  [(bad, a), (mid, n), (level, n), (experienced, v), (enquire, r), (properly, a), (joining, v), (r...
# 4     [(anything, n), (called, v), (work, n), (life, n), (balance, n), (.., n), (colum, n), (joke, n)]
#
#                                                                                             lemmatized  \
# 0                                                                              [good, managable, team]
# 1                                                                          [balance, rarely, pressure]
# 2  [work, hour, 9:30, hour, shift, allowance, shift, get, changed, weekly, basis, sometimes, week, ...
# 3  [bad, mid, level, experience, enquire, properly, join, role, responsibility, close, circle, hr, ...
# 4                                               [anything, call, work, life, balance, .., colum, joke]
#
#                                                                                              lemma_str  \
# 0                                                                                  good managable team
# 1                                                                              balance rarely pressure
# 2  work hour 9:30 hour shift allowance shift get changed weekly basis sometimes week 2 day morning ...
# 3  bad mid level experience enquire properly join role responsibility close circle hr interviewer w...
# 4                                                        anything call work life balance .. colum joke
#
#                                                                                      sentiment_results  \
# 0        {'polarity_blob': 0.7, 'subjectivity_blob': 0.6000000000000001, 'sentiment_blob': 'Positive'}
# 1                       {'polarity_blob': 0.3, 'subjectivity_blob': 0.9, 'sentiment_blob': 'Positive'}
# 2  {'polarity_blob': -0.24999999999999997, 'subjectivity_blob': 0.2611111111111111, 'sentiment_blob...
# 3  {'polarity_blob': -0.11249999999999996, 'subjectivity_blob': 0.25416666666666665, 'sentiment_blo...
# 4                        {'polarity_blob': 0.0, 'subjectivity_blob': 0.0, 'sentiment_blob': 'Neutral'}
#
#    polarity_blob  subjectivity_blob sentiment_blob  \
# 0         0.7000           0.600000       Positive
# 1         0.3000           0.900000       Positive
# 2        -0.2500           0.261111       Negative
# 3        -0.1125           0.254167       Negative
# 4         0.0000           0.000000        Neutral
#
#                                                       scores_vader  \
# 0     {'neg': 0.0, 'neu': 0.408, 'pos': 0.592, 'compound': 0.4404}
# 1     {'neg': 0.0, 'neu': 0.514, 'pos': 0.486, 'compound': 0.2235}
# 2  {'neg': 0.114, 'neu': 0.844, 'pos': 0.042, 'compound': -0.4939}
# 3  {'neg': 0.136, 'neu': 0.778, 'pos': 0.086, 'compound': -0.3182}
# 4      {'neg': 0.0, 'neu': 0.761, 'pos': 0.239, 'compound': 0.296}
#
#    compound_vader sentiment_vader
# 0          0.4404        Positive
# 1          0.2235        Positive
# 2         -0.4939        Negative
# 3         -0.3182        Negative
# 4          0.2960        Positive

# %%
sns.countplot(clean['sentiment_vader'])
# Out:
# C:\Users\Anindita\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sentiment_vader', ylabel='count'>

# %%
sns.countplot(y ='company', hue = 'sentiment_vader', data = clean)
# Out:
# <AxesSubplot:xlabel='count', ylabel='company'>

# %%
plt.figure(figsize=(50,30))
sns.histplot(data=clean, x="compound_vader", color="green", label="Overall Rating Score", kde=True)
sns.histplot(data=clean, x="polarity_blob", color="red", label="Sentiment Distribution", kde=True)

plt.legend() 
plt.show()

# %%
sns.scatterplot(data=clean, x="compound_vader", y="polarity_blob", hue="company")
# Out:
# <AxesSubplot:xlabel='compound_vader', ylabel='polarity_blob'>

# %%
# Extracting the desired variables for analysis
sentiment = clean.loc[:, ['compound_vader','polarity_blob']]

# %%
sns.kdeplot(data=sentiment)
# Out:
# <AxesSubplot:ylabel='Density'>
