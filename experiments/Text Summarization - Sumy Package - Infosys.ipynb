# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Anindita\\Documents\\ISB\\Capstone Project\\Projects\\Capstone Peak Health\\Code\\Text Summarization'

# %%
# Importing the libraries

from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.nlp.stemmers import Stemmer
from sumy.utils import get_stop_words
 
from sumy.summarizers.lex_rank import LexRankSummarizer 
from sumy.summarizers.luhn import LuhnSummarizer
from sumy.summarizers.lsa import LsaSummarizer
from sumy.summarizers.text_rank import TextRankSummarizer
from sumy.summarizers.edmundson import EdmundsonSummarizer
from sumy.summarizers.kl import KLSummarizer
from sumy.summarizers.reduction import ReductionSummarizer

from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
language = "english"
sentence_count = 5

# %% [markdown]
# ### Infosys Review Text

# %%
def summarize(text, summarizer, sentence_count, bonus_words=['work life balance', 'security', 'environment', 'growth', 'salary', 'culture', 'career' ,'pay', 'exhaustion', 'detachment', 'improvement'], language='english'):
    summarizer = summarizer(Stemmer(language))
    summarizer.stop_words = get_stop_words(language)
    if isinstance(summarizer, EdmundsonSummarizer):
        summarizer.bonus_words = bonus_words
        summarizer.stigma_words = ['I', 'am', 'the', 'are', 'me', 'is', 'than', 'that', 'this', 'NA', 'we', 'it', 'you', 'was']
        summarizer.null_words = get_stop_words(language)
    summary = summarizer(PlaintextParser.from_file("infosys0730.txt", Tokenizer(language)).document, sentence_count)
    return summary

# %%
def print_summary(summary):
    for sentence in summary:
        print(sentence)
        print("\n----")

# %%
for summarizer in [LexRankSummarizer, LuhnSummarizer, LsaSummarizer, TextRankSummarizer,
                   EdmundsonSummarizer, KLSummarizer, ReductionSummarizer]:
    print('*' + summarizer.__name__ + '*')
    print_summary(summarize(summary,
                            summarizer,
                            sentence_count,
                            bonus_words=['work life balance', 'security', 'environment', 'growth', 'salary', 'culture', 'career' ,'pay', 'exhaustion', 'detachment', 'improvement']))
    print()
# Out:
# *LexRankSummarizer*
# good work life balance in development projects.
#
# ----
# Only Work!
#
# ----
# Good No work life balance Free and good Currently great due to WFH, on an average good, depends on clients and managers Good Good work environment and culture Overall good No work life balance Good BI Lead Comfortable Fine Hectic and sucking Good work in Infosys company Fun every topic you mind discuss enjoy Best in life training at mysuru❤️ Work life was good Good and decent My work life has been good.
#
# ----
# Work from.
#
# ----
# So extra time is almost daily routine Good The job is quite interesting My project had hectic schedule..so we have challenge Excellent Support project Good Good Work is good Good Nice culture.
#
# ----
#
# *LuhnSummarizer*
# ...

# %% [markdown]
# ### Infosys Pune Review Text

# %%
def summarize(text, summarizer, sentence_count, bonus_words=['work life balance', 'security', 'environment', 'growth', 'salary', 'culture', 'career' ,'pay', 'exhaustion', 'detachment', 'improvement'], language='english'):
    summarizer = summarizer(Stemmer(language))
    summarizer.stop_words = get_stop_words(language)
    if isinstance(summarizer, EdmundsonSummarizer):
        summarizer.bonus_words = bonus_words
        summarizer.stigma_words = ['I', 'am', 'the', 'are', 'me', 'is', 'than', 'that', 'this', 'NA', 'we', 'it', 'you', 'was']
        summarizer.null_words = get_stop_words(language)
    summary = summarizer(PlaintextParser.from_file("infosyspune0730.txt", Tokenizer(language)).document, sentence_count)
    return summary

def print_summary(summary):
    for sentence in summary:
        print(sentence)
        print("\n----")
        

for summarizer in [LexRankSummarizer, LuhnSummarizer, LsaSummarizer, TextRankSummarizer,
                   EdmundsonSummarizer, KLSummarizer, ReductionSummarizer]:
    print('*' + summarizer.__name__ + '*')
    print_summary(summarize(summary,
                            summarizer,
                            sentence_count,
                            bonus_words=['work life balance', 'security', 'environment', 'growth', 'salary', 'culture', 'career' ,'pay', 'exhaustion', 'detachment', 'improvement']))
    print()
# Out:
# *LexRankSummarizer*
# Very fantastic 😊 Average No work life balance Currently great due to WFH, on an average good, depends on clients and managers Good Good work in Infosys company Best in life training at mysuru❤️ Work life was good My work life has been good.
#
# ----
# Life time Work life is satisfactory It's very good Ok Good Work life Balance is good Good They don't have much resource but lots to work...
#
# ----
# ok.....not so good as well as bad Interesting and challenging It was very hectic,lot of work pressure Good for me Average experience Almost all facility provided by Infosys are Paid one.
#
# ----
# ...

# %% [markdown]
# ### Infosys Pune Technology Analysts

# %%
def summarize(text, summarizer, sentence_count, bonus_words=['work life balance', 'security', 'environment', 'growth', 'salary', 'culture', 'career' ,'pay', 'exhaustion', 'detachment', 'improvement'], language='english'):
    summarizer = summarizer(Stemmer(language))
    summarizer.stop_words = get_stop_words(language)
    if isinstance(summarizer, EdmundsonSummarizer):
        summarizer.bonus_words = bonus_words
        summarizer.stigma_words = ['I', 'am', 'the', 'are', 'me', 'is', 'than', 'that', 'this', 'NA', 'we', 'it', 'you', 'was']
        summarizer.null_words = get_stop_words(language)
    summary = summarizer(PlaintextParser.from_file("infosyspuneTA0730.txt", Tokenizer(language)).document, sentence_count)
    return summary

def print_summary(summary):
    for sentence in summary:
        print(sentence)
        print("\n----")
        

for summarizer in [LexRankSummarizer, LuhnSummarizer, LsaSummarizer, TextRankSummarizer,
                   EdmundsonSummarizer, KLSummarizer, ReductionSummarizer]:
    print('*' + summarizer.__name__ + '*')
    print_summary(summarize(summary,
                            summarizer,
                            sentence_count,
                            bonus_words=['work life balance', 'security', 'environment', 'growth', 'salary', 'culture', 'career' ,'pay', 'exhaustion', 'detachment', 'improvement']))
    print()
# Out:
# *LexRankSummarizer*
# Good Manageable work life balance No work life balance It is great at the moment, but again this is something that will depend on the project you will be working on.
#
# ----
# Cool Work is exciting and open to opportunities Boring Good Developer in JAVA, Spring and Hibernate Interesting and challenging Awesome.. Hectix It's boring and mostly processes are terrible Hectic but a lot to learn from Worst work Exciting Awesome Good Woring Overall good experience.
#
# ----
# Worst part is you are not getting skilled after all this grilling Good work life but might vary project to project.
#
# ----
# Good Great Good and healthy Good Good Worst work culture.
#
# ----
# Good It was good and very enjoyable 🙂 Work life is good I would say my work life balance is fair at infosys.
#
# ----
#
# *LuhnSummarizer*
# ...
